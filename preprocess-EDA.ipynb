# %%
# !pip install langdetect
# !pip install googletrans==4.0.0rc1
# !pip install googletrans==3.1.0a0 
# !pip install google-cloud-translate==2.0.1
# !pip install -U easynmt
# !pip install torch torchvision torchaudio
# !pip install bertopic
# !pip install pyLDAvis -qq
# !pip install -qq -U gensim
# !pip install seaborn -qq
# !python -m spacy download en_core_web_md -qq

# %%
# import libraries used
import pandas as pd
import numpy as np
import re               # regular expression library
import nltk
import time
import string
from nltk.corpus import stopwords
from nltk.tokenize import (RegexpTokenizer, word_tokenize)
from nltk.corpus import names
from nltk.corpus import wordnet as wn
from googletrans import Translator
from langdetect import detect
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
import seaborn as sns
sns.set()
import spacy
import en_core_web_md
from gensim.utils import simple_preprocess

# %% [markdown]
#   # Data Pre-proprocess

# %% [markdown]
#   ### Load data

# %%
sgReviews = pd.read_csv('./SG/SG-reviews.csv')
thReviews = pd.read_csv('./TH/TH-reviews.csv')
trReviews = pd.read_csv('./TR/TR-reviews.csv')

sgList = pd.read_csv('./SG/SG-listings.csv')
thList = pd.read_csv('./TH/TH-listings.csv')
trList = pd.read_csv('./TR/TR-listings.csv')

# %% [markdown]
# ### Add column: Country, for easy differentiation

# %%
sg = []
i = 0
len(sgReviews)
while i < len(sgReviews):
    sg.append("Singapore")
    i +=1

sgReviews['Country'] = sg
len(sg)

# %%
th = []
i = 0
len(thReviews)
while i < len(thReviews):
    th.append("Thailand")
    i +=1

thReviews['Country'] = th
len(th)

# %%
tr = []
i = 0
len(trReviews)
while i < len(trReviews):
    tr.append("Turkey")
    i +=1

trReviews['Country'] = tr
len(tr)

# %% [markdown]
#   ### Data removal - remove irrelevant data

# %% [markdown]
#  ##### drop unecessary columns

# %%
# save columns in reviews dataframe that are needed for later analyses
sgReviewsTrim = sgReviews[['listing_id', 'comments', 'Country']]
thReviewsTrim = thReviews[['listing_id', 'comments', 'Country']]
trReviewsTrim = trReviews[['listing_id', 'comments', 'Country']]

# column name-change listing_id to id
sgReviewsTrim = sgReviewsTrim.rename(columns = {'listing_id':'id'})
thReviewsTrim = thReviewsTrim.rename(columns = {'listing_id':'id'})
trReviewsTrim = trReviewsTrim.rename(columns = {'listing_id':'id'})

# %%
# only include column in listing useful for later analyses
sgListingsTrim = sgList[['id', 'review_scores_rating', 'review_scores_cleanliness',
                        'review_scores_communication', 'review_scores_location',
                        'review_scores_value']]

thListingsTrim = thList[['id', 'review_scores_rating', 'review_scores_cleanliness',
                        'review_scores_communication', 'review_scores_location',
                        'review_scores_value']]

trListingsTrim = trList[['id', 'review_scores_rating', 'review_scores_cleanliness',
                        'review_scores_communication', 'review_scores_location',
                        'review_scores_value']]

# %%
# merge reviews and listings dataframes
sgTots = pd.merge(sgReviewsTrim, sgListingsTrim, on = 'id')
thTots = pd.merge(thReviewsTrim, thListingsTrim, on = 'id')
trTots = pd.merge(trReviewsTrim, trListingsTrim, on = 'id')

# concat the data into "result"
result = pd.concat([sgTots, thTots, trTots], axis = 0)
# result = pd.concat([sgTots, thTots, trTots])
result.head(-10)

# %% [markdown]
#   ##### drop null values & duplicates

# %%
print("Before dropna: ", len(result))
# dropna function will remove any NA value from all the columns
result = result.dropna(axis=0, how='any')
print("After dropna: ", len(result))

print("Before drop duplicates: ", len(result))
result = result.drop_duplicates(subset=["comments"])
print("After drop duplicates: ", len(result))
# Out:
# Before dropna:  890121
# After dropna:  889722
# Before drop duplicates:  889722
# After drop duplicates:  846925

# %% [markdown]
#   ##### remove irrelevant data
#   such as: " " or "-" or "--" or "/" or "." or "123"

# %%
ls = [" ", "-", "--", "/", ".", "123"]
for i in ls:
    result = result.drop(result[result["comments"] == i].index)
len(result)

# %% [markdown]
#   ##### remove automated reviews

# %%
# create a column to check whether a review is an automated posting (yes, no)
def autopost(x):
    if 'an automated posting' in x:
        return 'yes'
    else:
        return 'no'
result['auto_posting'] = result['comments'].apply(autopost)
result = result.loc[result['auto_posting']=='no']
len(result)

# %% [markdown]
#   ##### Note: read before proceed
#   based on the dataframe "result" above, the numbers of the data is not valid: </br>
#   ![image.png](attachment:image.png)
#   - see num of last row: 511612</br>
#   - see actual number of rows: 846706   846724</br>
#   <b>before proceed to translation, save the dataframe into CSV file, and open in EXCEL to smoothen the numbers.</br>
#   </br>
#   <b> **NOTE** after deep into this project, i found a way to remove these index numbers when saving to CSV. However, I didn't change the code, because it doesn't matter anymore. </br>
#   </br>
#   <b>But the code is this: result.to_csv("filename.csv", index=False)

# %%
# save df to csv
result.to_csv("data.csv")
# ## code below is for removing index number when saving data to CSV
# result.to_csv("data.csv", index="False")

# %% [markdown]
#   ### translate non-english to english

# %%
# load records from data
data = pd.read_csv("data1.csv")
data = data.drop(["Unnamed: 0", "auto_posting"], axis=1)

rev = []
data.head(-10)

# %%
# translate reviews
rev2 = []
translate = Translator()
for i in data["comments"].iloc[27540:33824]:
    translate.raise_Exception = True
    time.sleep(0.3)
    try:
        detect = translate.detect(i)
    except:
        detect = translate.detect(i)
    try: 
        if detect.lang == "en":
            rev2.append(i)
        else:
            translation = translate.translate(i)

            print("before trans: " + i)
            rev2.append(translation.text)
            print("after trans: " + translation.text)
    except:
        rev2.append("NonEng")

# %%
# print(data["comments"].iloc[199242:199252])
print(data["comments"].iloc[27536:33824])

# %%
# to view the data stored in the "rev2" list, before appending into "rev"
# so as not to mess up data in "rev"
print(len(rev2))
for i in rev2:
    print(i)

# %%
# to append the translated list: "rev2" into the "rev"
print("rev: ", len(rev))
print("rev2: ", len(rev2))
for j in rev2:
    rev.append(j)
    print(j)
print(len(rev))
# print(len(rev) + 33824)
# print(len(thRev) + 358647)

# %%
# for translated reviews' VERSION CONTROL
revv = pd.DataFrame(rev)
revv.to_csv("Rev.csv")

# %%
# the above code cells are needed, because the records are too huge (takes long time), if wifi down - translation'll be interupted, 
# therefore VERSIONING of the csv file is needed to track the translation.

# then i manually copy-paste the translated data to the original data thru EXCEL
# in the file "data1 - Copy.csv"

# %% [markdown]
#  #### remove duplicates again, after translate

# %%
data1Cop = pd.read_csv(r"data1 - Copy.csv", header=0)
data = pd.read_csv(r"data1.csv", header=0)
data1Cop.head()
data1 = data1Cop[['id', 'comments', 'transComments']]
data1

# %%
completeD = pd.merge(data, data1, on = ["comments", "id"])
completeD

# %%
print(len(completeD))
completeD = completeD.drop_duplicates(subset=["transComments"])
print("Data after drop_dup for translated: ", len(completeD))

# %%
completeD.to_csv("completeD.csv")

# %% [markdown]
# # Data Pre-process (after Sentiment Analysis)

# %%
data = pd.read_csv("completeD.csv").drop(["Unnamed: 0"], axis=1)

# %% [markdown]
# ### Remove Punctuation & Change Lowercase

# %%
# Simplification of of the data for Exploratary Data analysis
# remove punctuation, change to lowercase

data['cleanedTransCom'] = [re.sub(r'[,\.!?]', '', str(x)) for x in data['transComments']]
data['cleanedTransCom'] = [re.sub(r'http\S+', '', str(x)) for x in data['cleanedTransCom']]
data['cleanedTransCom'] = [re.sub(r'[^A-Za-z]+', ' ', str(x)) for x in data['cleanedTransCom']]
data['cleanedTransCom'] = data['cleanedTransCom'].map(lambda x: x if type(x)!=str else x.lower())

# %% [markdown]
# ### Tokenise & Lemmatise

# %%
# tokenise & lemmatise & stopwords removal on the translated, cleaned comments for WORDCLOUD purpose
nltk.download('stopwords')
nltk.download('wordnet')
def clean_comments(text):
    
    words = nltk.word_tokenize(text)    
    # words2 = nltk.tokenize.WhitespaceTokenizer()
    
    stopwordsVocab = stopwords.words('english')
    moreTOExclue = ['br', 's', 'd', 'be']
    stopwordsVocab.extend(moreTOExclue)
    
    filtered_text = [word for word in words if word not in stopwordsVocab]

    lemmatizer = nltk.stem.WordNetLemmatizer()
    lemmatized_text = [lemmatizer.lemmatize(token) for token in filtered_text]
    return lemmatized_text
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Gead
# [nltk_data]     Kee\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Gead
# [nltk_data]     Kee\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data['tokensForWordcloud'] = data["cleanedTransCom"].apply(clean_comments)

# %% [markdown]
#   #### Remove Unwanted Tags like: adverb, pronoun, conjunction, etc.

# %%
nlp = en_core_web_md.load()

# Tags I want from the text
allowed_postags = ['NOUN', 'ADJ', 'VERB']
tokens = []

for i in nlp.pipe(data['cleanedTransCom']):
   proj_tok = [token.lemma_ for token in i if token.pos_ in allowed_postags]
   tokens.append(proj_tok)

tokens
# Out:
# [['room', 'clean', 'tidy', 'bed', 'comfortable'],
#  ['good',
#   'space',
#   'interesting',
#   'home',
#   'quiet',
#   'location',
#   'lovely',
#   'park',
#   'road',
#   'rare',
#   'nice',
#   'place',
#   'big',
#   'group'],
#  ['comfortable',
#   'place',
#   'kind',
#   'helpful',
#   'woman',
#   'nice',
#   'accommodation',
#   'tourism',
#   'site',
#   'place',
#   'beautiful',
#   'calm',
#   'maid',
#   'helpful',
#   'br',
#   'nice',
#   'trip',
#   'beautiful',
#   'singapore'],
#  ['mature',
#   'age',
#   'traveller',
#   'night',
#   'warm',
#   'reception',
#   'arrival',
#   'usual',
#   'case',
#   'short',
#   'taxi',
#   'ride',
#   'city',
#   'centre',
#   'near',
#   'bus',
#   'stop',
#   'train',
#   'station',
#   'first',
#   'train',
#   'ticket',
#   'excellent',
#   'customer',
#   'bedroom',
#   'air',
#   'clean',
#   'departure',
#   'belinda',
#   'gracious',
#   'helpful',
#   'recommendation',
#   'time',
#   'concerned',
#   'good',
#   'town',
#   'visitor'],
#  ['great',
#   'host',
#   'house',
#   'room',
#   'spotless',
#   'clean',
#   'presentable',
#   'comfortable',
#   'location',
#   'convenient',
#   'minute',
#   'bus',
#   'stop',
#   'bus',
#   'station',
#   'bus',
#   'street',
#   'quiet',
#   'small',
#   'park',
#   'child',
#   'playground',
#   'simple',
#   'fit',
#   'facility',
#   'thank'],
#  ['happy',
#   'holiday',
#   'kind',
#   'helpful',
#   'nice',
#   'comfortable',
#   'thing',
#   'little',
#   'downtown'],
#  ['good', 'host', 'great'],
#  ['apartment', 'friend', 'airbnb', 'happy', 'apartment', 'same', 'picture'],
#  ['room',
#   'people',
#   'day',
#   'room',
#   'double',
#   'bed',
#   'single',
#   'bed',
#   'other',
#   'room',
#   'double',
#   'bed',
#   'broken',
#   'bed',
#   'frame',
#   'wooden',
#   'board',
#   'room',
#   'same',
#   'bathroom',
#   'landlord',
#   'maid',
#   'situation',
#   'obvious',
#   'responsibility',
#   'next',
#   'morning',
#   'disappointing'],
#  ['couple',
#   'hour',
#   'early',
#   'morning',
#   'flight',
#   'house',
#   'keeper',
#   'super',
#   'warmwe',
#   'nice',
#   'stay'],
#  ['bad'],
#  ['attractive', 'place', 'pax'],
#  ['convenient', 'landlord', 'nice', 'enthusiastic', 'good', 'choice'],
#  ['location',
#   'close',
#   'expo',
#   'bus',
#   'stop',
#   'mrt',
#   'station',
#   'convenient',
#   'purpose',
#   'close'],
#  ['outstanding',
#   'value',
#   'money',
#   'place',
#   'upper',
#   'station',
#   'neighborhood',
#   'energy',
#   'night',
#   'sleep',
#   'restful'],
#  ['hepful', 'gast', 'lot', 'thing', 'hospitality'],
#  ['great', 'location', 'great', 'hospitality'],
#  [],
#  ['checking', 'process', 'easy'],
#  ['home',
#   'pleasant',
#   'stay',
#   'safe',
#   'care',
#   'night',
#   'flexible',
#   'baggage',
#   'evening',
#   'hassle',
#   'luggage',
#   'new',
#   'place',
#   'bread',
#   'cheese',
#   'breakfast',
#   'lot',
#   'time',
#   'morning',
#   'rush',
#   'hour',
#   'work',
#   'appreciative',
#   'hospitality'],
#  ['amazing', 'place', 'clean', 'stylish', 'great', 'swimming', 'dream', 'eye'],
#  ['location',
#   'private',
#   'near',
#   'bus',
#   'place',
#   'clean',
#   'stylish',
#   'touch',
#   'corner',
#   'house',
#   'host',
#   'contactable',
#   'responsive',
#   'check',
#   'check',
#   'friendly',
#   'good',
#   'experience',
#   'place'],
#  ['great',
#   'host',
#   'stay',
#   'enjoyable',
#   'time',
#   'nice',
#   'arranging',
#   'helpful',
#   'space',
#   'apartment',
#   'peaceful',
#   'good',
#   'facility',
#   'location',
#   'side'],
#  ['place', 'great', 'clean', 'cozy', 'friendly', 'host', 'place', 'star'],
#  ['amazed',
#   'interior',
#   'design',
#   'house',
#   'outstanding',
#   'queen',
#   'bed',
#   'comfy',
#   'toilet',
#   'room',
#   'location',
#   'min',
#   'bus',
#   'condo',
#   'great',
#   'experience',
#   'room',
#   'available',
#   'thank',
#   'helpful',
#   'accomodative',
#   'host'],
#  ['clean', 'apartment', 'great', 'pool', 'close', 'access'],
#  ['good',
#   'host',
#   'attention',
#   'modern',
#   'amenity',
#   'great',
#   'location',
#   'airport'],
#  ['one', 'airport', 'clean', 'cool', 'flexible', 'compound', 'care'],
#  ['place',
#   'clean',
#   'comfortable',
#   'close',
#   'airport',
#   'host',
#   'accessible',
#   'place',
#   'close',
#   'airport'],
#  ['place', 'stylish', 'modern', 'decoration', 'stay', 'perfect'],
#  ['clean',
#   'tidy',
#   'room',
#   'shared',
#   'apartment',
#   'area',
#   'easy',
#   'access',
#   'airport'],
#  ['classy',
#   'stylish',
#   'private',
#   'sophisticated',
#   'option',
#   'near',
#   'easy',
#   'taxi',
#   'other',
#   'transport',
#   'communication',
#   'fast',
#   'clear',
#   'excellent',
#   'detailed',
#   'instruction',
#   'stay',
#   'fortunate',
#   'privacy',
#   'space',
#   'warm',
#   'person',
#   'communication',
#   'space',
#   'modern',
#   'upscale',
#   'residential',
#   'area',
#   'shopping',
#   'restaurant',
#   'nice',
#   'coffee',
#   'tea',
#   'arrival',
#   'snack',
#   'item',
#   'lightweight',
#   'breathable',
#   'clothe',
#   'hot',
#   'humid',
#   'most',
#   'month',
#   'year',
#   'proximity',
#   'equator',
#   'room',
#   'air',
#   'conditioning',
#   'outside',
#   'environment',
#   'hot',
#   'warm',
#   'rain',
#   'proximity',
#   'safe',
#   'country',
#   'clean',
#   'many',
#   'garden',
#   'beautiful',
#   'touch',
#   'brief',
#   'airport',
#   'connection',
#   'pleasant',
#   'visit'],
#  ['room',
#   'cozy',
#   'clean',
#   'big',
#   'flat',
#   'new',
#   'clean',
#   'only',
#   'minute',
#   'airport',
#   'business',
#   'park',
#   'minute',
#   'city',
#   'flat',
#   'suitable',
#   'short',
#   'business',
#   'trip',
#   'cbp',
#   'tourist',
#   'quiet',
#   'place',
#   'accessible',
#   'host',
#   'homely',
#   'atmosphere',
#   'privacy',
#   'helpful',
#   'advice',
#   'little',
#   'baby',
#   'quiet',
#   'place',
#   'short',
#   'long'],
#  ['condominium',
#   'nice',
#   'minute',
#   'airport',
#   'taxi',
#   'room',
#   'clean',
#   'comfortable',
#   'cozy',
#   'polite',
#   'sure',
#   'comfortable',
#   'room',
#   'night',
#   'place',
#   'condominium',
#   'morning',
#   'sure',
#   'cab',
#   'am',
#   'flight',
#   'quick',
#   'access',
#   'airport',
#   'comfortable',
#   'room',
#   'bed',
#   'polite',
#   'helpful',
#   'courteous',
#   'host'],
#  ['family',
#   'welcoming',
#   'way',
#   'bus',
#   'station',
#   'friend',
#   'middle',
#   'dinner',
#   'gracious',
#   'door',
#   'am',
#   'room',
#   'great',
#   'tv',
#   'air',
#   'con',
#   'perfect',
#   'stop',
#   'airport',
#   'minute',
#   'close',
#   'bus',
#   'stop'],
#  ['excellent',
#   'stay',
#   'family',
#   'specific',
#   'private',
#   'room',
#   'condo',
#   'residence',
#   'bed',
#   'comfortable',
#   'bathroom',
#   'few',
#   'step',
#   'hallway',
#   'private',
#   'room',
#   'nice',
#   'nook',
#   'corner',
#   'view',
#   'courtyard',
#   's',
#   'less',
#   'minute',
#   'taxi',
#   'ride',
#   'residence',
#   'airport',
#   'excellent',
#   'direction',
#   'mtr',
#   'station',
#   'bus',
#   'stop',
#   'minute',
#   'bus',
#   'minute',
#   'mtr',
#   'station',
#   'place',
#   'airport',
#   'convenient'],
#  ['first',
#   'timer',
#   'airbnb',
#   'unsure',
#   'room',
#   'host',
#   'welcoming',
#   'helpful',
#   'neighbourhood',
#   'grateful',
#   'host',
#   'last',
#   'minute',
#   'request',
#   'husband',
#   'fun',
#   'due',
#   'work',
#   'other',
#   'thing',
#   'whole',
#   'area',
#   'condo',
#   'beautiful',
#   'room',
#   'clean',
#   'spacious',
#   'super',
#   'fast',
#   'internet',
#   'description',
#   'unfortunate',
#   'agreement',
#   'room',
#   'tv',
#   'different',
#   'room',
#   'less',
#   'tv',
#   'experience',
#   'bit'],
#  ['host',
#   'friendly',
#   'manner',
#   'bus',
#   'place',
#   'work',
#   'card',
#   'bus',
#   'own',
#   'overall',
#   'room',
#   'good',
#   'room',
#   'other',
#   'traveller',
#   'room',
#   'clean',
#   'listing',
#   'environment',
#   'beautiful',
#   'room',
#   'condominium',
#   'ground',
#   'condominium',
#   'swimming',
#   'pool',
#   'atmosphere',
#   'condominium',
#   'garden',
#   'peaceful'],
#  ['great',
#   'family',
#   'stay',
#   'crazy',
#   'hour',
#   'lot',
#   'time',
#   'month',
#   'room',
#   'family',
#   'room',
#   'lovely',
#   'city',
#   'center',
#   'ideal',
#   'location',
#   'craziness',
#   'calming',
#   'area',
#   'beautiful',
#   'condo',
#   'heap',
#   'facility',
#   'br',
#   'home',
#   'home'],
#  ['resort',
#   'appearance',
#   'nice',
#   'pool',
#   'weight',
#   'room',
#   'small',
#   'bowling',
#   'alley',
#   'bathroom',
#   'hall',
#   'private',
#   'housekeeper',
#   'dish',
#   'meat',
#   'house',
#   'professional',
#   'people',
#   'month',
#   'yr',
#   'old',
#   'daughter',
#   'behaved',
#   'friendly',
#   'whole',
#   'family',
#   'welcoming'],
#  ['perfect',
#   'location',
#   'responsive',
#   'host',
#   'small',
#   'limited',
#   'daylight',
#   'room',
#   'limited',
#   'kitchen'],
#  ['nice', 'accommodation', 'option', 'excellent', 'location'],
#  ['clean', 'public', 'area', 'bit', 'small', 'pity', 'good'],
#  ['door',
#   'hostile',
#   'room',
#   'full',
#   'people',
#   'host',
#   'warm',
#   'welcome',
#   'air',
#   'conditioning',
#   'dormitory',
#   'strong',
#   'taste',
#   'clean',
#   'hostel'],
#  ['nice', 'hostel', 'easy', 'bathroom', 'clean', 'location'],
#  ['way', 'hostel'],
#  ['royal',
#   'nice',
#   'place',
#   'chinatown',
#   'friendly',
#   'people',
#   'nice',
#   'breakfast',
#   'clean',
#   'bed'],
#  ['nearby',
#   'chinatown',
#   'trip',
#   'location',
#   'worth',
#   'hostel',
#   'clean',
#   'manager',
#   'management'],
#  ['clean',
#   'quiet',
#   'place',
#   'room',
#   'crowded',
#   'people',
#   'top',
#   'bed',
#   'easy',
#   'fast',
#   'solution',
#   'cheap',
#   'accommodation',
#   'city'],
#  ['royal',
#   'hostel',
#   'great',
#   'place',
#   'chinatown',
#   'ton',
#   'restaurant',
#   'souvenir',
#   'min',
#   'hostel',
#   'convenient',
#   'hostel',
#   'clean',
#   'bed',
#   'comfy',
#   'br'],
#  ['good',
#   'location',
#   'earth',
#   'chinatown',
#   'close',
#   'clean',
#   'am',
#   'toilet',
#   'old',
#   'hot',
#   'price',
#   'good',
#   'night'],
#  ['accommodation',
#   'description',
#   'accurate',
#   'easy',
#   'bit',
#   'difficult',
#   'way',
#   'first',
#   'trip',
#   'station',
#   'exit',
#   'exit',
#   'staff',
#   'friendly'],
#  ['wordfantastic',
#   'organised',
#   'clean',
#   'class',
#   'accommodation',
#   'backpacker',
#   'hostel',
#   'superb',
#   'location',
#   'royal',
#   'middle',
#   'chinatown',
#   'food',
#   'street',
#   'street',
#   'hostel',
#   'peaceful'],
#  ['star',
#   'great',
#   'area',
#   'location',
#   'openness',
#   'useful',
#   'helpful',
#   'first',
#   'timer'],
#  ['bed',
#   'royal',
#   'washer',
#   'dryer',
#   'close',
#   'food',
#   'court',
#   'stair',
#   'convenience',
#   'food',
#   'stamp',
#   'dollar',
#   'breakfast',
#   'other',
#   'location',
#   'equal',
#   'coffee',
#   'toast',
#   'clean',
#   'bed',
#   'air'],
#  ['royal',
#   'first',
#   'time',
#   'hostel',
#   'room',
#   'tidy',
#   'comfortable',
#   'great',
#   'experience',
#   'hostel'],
#  ['great',
#   'place',
#   'stay',
#   'chinatown',
#   'cultural',
#   'historical',
#   'point',
#   'distance',
#   'hostel',
#   'clean',
#   'neat'],
#  ['nice', 'cleangreat', 'middle', 'chinatownlot', 'great', 'food'],
#  ['clean', 'good', 'location', 'kind', 'people', 'hostel'],
#  ['good',
#   'place',
#   'location',
#   'ideal',
#   'fun',
#   'close',
#   'chinatown',
#   'train',
#   'station',
#   'entire',
#   'city'],
#  ['kind',
#   'host',
#   'need',
#   'much',
#   'interaction',
#   'warm',
#   'respectful',
#   'room',
#   'spacious',
#   'cupboard',
#   'luggage',
#   'other',
#   'furniture',
#   'easy',
#   'shower',
#   'shower',
#   'room',
#   'convenient',
#   'shortcut',
#   'bus',
#   'used'],
#  ['responsive',
#   'call',
#   'email',
#   'helpful',
#   'direction',
#   'house',
#   'ride',
#   'extra',
#   'mattress',
#   'son',
#   'taxi',
#   'overall',
#   'night',
#   'place',
#   'pleasant',
#   'worth',
#   'money',
#   'location',
#   'close',
#   'downtown',
#   'close',
#   'airport',
#   'ferry',
#   'plus'],
#  ['interesting',
#   'guest',
#   'house',
#   'convenient',
#   'airport',
#   'short',
#   'stay',
#   'thank'],
#  ['place',
#   'nice',
#   'necessary',
#   'toiletry',
#   'coffee',
#   'water',
#   'shortcut',
#   'place',
#   'night',
#   'next',
#   'day'],
#  ['night',
#   'room',
#   'airport',
#   'family',
#   'group',
#   'small',
#   'child',
#   'simple',
#   'cheap',
#   'place',
#   'difficult',
#   'hotel',
#   'room',
#   'extra',
#   'bed',
#   'floor',
#   'small',
#   'kid',
#   'room',
#   'room',
#   'responsive',
#   'query',
#   'arrival',
#   'other',
#   'people',
#   'house',
#   'big',
#   'house',
#   'friendly',
#   'reception',
#   'extra',
#   'floor',
#   'bed',
#   'kid',
#   'room',
#   'great',
#   'room',
#   'clean',
#   'comfortable',
#   'little',
#   'bit',
#   'decor',
#   'basic',
#   'bathroom',
#   'guest',
#   'room',
#   'co',
#   'helpful',
#   'taxi',
#   'trip',
#   'zoo',
#   'airport',
#   'day',
#   'departure',
#   'good',
#   'experience',
#   'cheap',
#   'basic',
#   'clean',
#   'comfortable',
#   'accommodation',
#   'airport',
#   'good',
#   'option',
#   'belinda',
#   'professional',
#   'friendly',
#   'approach',
#   'whole',
#   'experience'],
#  ['house',
#   'convenient',
#   'day',
#   'minute',
#   'airport',
#   'routine',
#   'bus',
#   'end',
#   'street',
#   'turn',
#   'road',
#   'close',
#   'bus',
#   'stop',
#   'short',
#   'walk',
#   'park',
#   'house',
#   'right',
#   'minute',
#   'close',
#   'shop',
#   'washing',
#   'machine',
#   'maid',
#   'slipper',
#   'back',
#   'door',
#   'work',
#   'area',
#   'clothe',
#   'rack',
#   'air',
#   'space',
#   'bedroom',
#   'internet',
#   'connectivity',
#   'good',
#   'child',
#   'thank',
#   'airport',
#   'transfer',
#   'bus',
#   'stop',
#   'end',
#   'street',
#   'terminal',
#   'cost',
#   'person'],
#  ['budget',
#   'choice',
#   'responsive',
#   'helpful',
#   'professional',
#   'room',
#   'clean',
#   'spacious',
#   'fridge',
#   'closet',
#   'min',
#   'downtown',
#   'public',
#   'transportation',
#   'sytem'],
#  ['place',
#   'near',
#   'destination',
#   'mother',
#   'few',
#   'bus',
#   'fair',
#   'price',
#   'fair',
#   'room',
#   'bathroom',
#   'tenant',
#   'next',
#   'door',
#   'bathroom',
#   'smell',
#   'next',
#   'day',
#   'bathroom',
#   'shame',
#   'tenant',
#   'housemaid',
#   'friendly',
#   'name',
#   'many',
#   'area',
#   'cab',
#   'airport',
#   'end',
#   'trip',
#   'overall',
#   'pleasant',
#   'trip'],
#  ['lovely',
#   'stay',
#   'friendly',
#   'fantastic',
#   'welcome',
#   'morning',
#   'house',
#   'nice',
#   'cozy',
#   'neighborhood',
#   'great',
#   'place',
#   'long',
#   'flight'],
#  ['family',
#   'perfect',
#   'host',
#   'beautiful',
#   'home',
#   'comfortable',
#   'other',
#   'guest',
#   'family',
#   'home',
#   'future',
#   'trip'],
#  ['room',
#   'beautiful',
#   'home',
#   'belinda',
#   'family',
#   'welcome',
#   'early',
#   'morning',
#   'shared',
#   'bathroom',
#   'bedroom',
#   'other',
#   'room'],
#  ['bus',
#   'airport',
#   'clean',
#   'average',
#   'size',
#   'suite',
#   'bathroom',
#   'hotel',
#   'sufficient',
#   'fi',
#   'tea',
#   'coffee',
#   'facility',
#   'room',
#   'good',
#   'quality',
#   'price',
#   'ratio',
#   'central',
#   'min',
#   'bus',
#   'train',
#   'city',
#   'hotel',
#   'check',
#   'form',
#   'arrival',
#   'interaction',
#   'host',
#   'cleaning',
#   'lady',
#   'house',
#   'fridge',
#   'room',
#   'kitchen',
#   'cold',
#   'air',
#   'side',
#   'bed',
#   'flue',
#   'night'],
#  ['convenient',
#   'location',
#   'airport',
#   'room',
#   'large',
#   'clean',
#   'personal',
#   'touch',
#   'several',
#   'cool',
#   'drink',
#   'bar',
#   'fridge',
#   'welcome',
#   'long',
#   'hot',
#   'flight',
#   'many',
#   'several',
#   'lounge',
#   'area',
#   'other',
#   'guest',
#   'warm',
#   'welcome',
#   'staff',
#   'member',
#   'luggage',
#   'room',
#   'taxi',
#   'departure',
#   'next',
#   'day',
#   'staff',
#   'friendly',
#   'ready',
#   'request',
#   'short',
#   'walk',
#   'minute',
#   'minute',
#   'excellent',
#   'food',
#   'court',
#   'people',
#   'holiday',
#   'busy',
#   'city'],
#  ['friendly', 'helpful', 'people', 'room', 'clean', 'expectation'],
#  ['room',
#   'comfortable',
#   'spacious',
#   'close',
#   'airport',
#   'friendly',
#   'helpful',
#   'host'],
#  ['night',
#   'night',
#   'bullet',
#   'trip',
#   'unable',
#   'other',
#   'guest',
#   'short',
#   'stay'],
#  ['room',
#   'airport',
#   'subway',
#   'line',
#   'convenient',
#   'room',
#   'bathroom',
#   'cleanliness',
#   'good',
#   'breakfast',
#   'rice',
#   'noodle',
#   'egg',
#   'bit',
#   'simple'],
#  ['nice',
#   'experience',
#   'place',
#   'close',
#   'stc',
#   'room',
#   'clean',
#   'bed',
#   'comfortable',
#   'breakfast',
#   'maid',
#   'great',
#   'help',
#   'bike',
#   'shopping',
#   'centre',
#   'food',
#   'court',
#   'pleasant',
#   'stay'],
#  ['friendly', 'great', 'host', 'stay'],
#  ['place', 'awesome', 'comfortable', 'affordable'],
#  ['hospitality',
#   'lasting',
#   'impression',
#   'family',
#   'chinese',
#   'culture',
#   'antique',
#   'calligraphy',
#   'painting',
#   'home',
#   'eye',
#   'opening',
#   'subway',
#   'station',
#   'meter',
#   'minute',
#   'subway',
#   'city',
#   'center',
#   'convenient',
#   'chance',
#   'next',
#   'time'],
#  ['nice', 'neighbourhood', 'great', 'place', 'airport'],
#  ['friendly',
#   'host',
#   'disturb',
#   'stay',
#   'comfortable',
#   'place',
#   'clean',
#   'environment',
#   'room',
#   'big',
#   'space',
#   'fiance',
#   'happy',
#   'request',
#   'host',
#   'work',
#   'purpose'],
#  ['place',
#   'airport',
#   'emergency',
#   'case',
#   'early',
#   'flight',
#   'second',
#   'day',
#   'late',
#   'wellyou',
#   'good',
#   'stay'],
#  ['great', 'stay', 'convenient', 'cosy', 'preferred', 'choice', 'business'],
#  ['good',
#   'customer',
#   'service',
#   'hostel',
#   'fact',
#   'comparable',
#   'service',
#   'star',
#   'staff',
#   'contact',
#   'lovely',
#   'helpful',
#   'amazed',
#   'photo',
#   'accurate',
#   'reflection',
#   'aircon',
#   'tv',
#   'much',
#   'multiple',
#   'option',
#   'internet',
#   'bathroom',
#   'easy',
#   'clean',
#   'bit',
#   'water',
#   'floor',
#   'sock',
#   'description',
#   'useful',
#   'noticeboard',
#   'similar',
#   'useful',
#   'noticeboard',
#   'hostel',
#   'time',
#   'day',
#   'thing',
#   'host',
#   't',
#   'way',
#   'hostel',
#   'time',
#   'thing',
#   'close',
#   'beautiful',
#   'mosque',
#   'prayer',
#   'loud',
#   'morning',
#   'course',
#   'host',
#   'lot',
#   'sleep',
#   'able',
#   'entire',
#   'night',
#   'accommodation',
#   'different',
#   'part',
#   'able',
#   'bodied',
#   'person',
#   'lot',
#   'luggage',
#   'room',
#   'ground',
#   'floor',
#   'lift',
#   'happy',
#   'level',
#   'stair',
#   'time',
#   'likely',
#   'hostel',
#   'lovely'],
#  ['great', 'stay'],
#  ['superb', 'stay'],
#  ['short', 'stay', 'time', 'great'],
#  ['convenient', 'place'],
#  ['preferred', 'choice'],
#  ['great', 'stay'],
#  ['short', 'stay', 'time'],
#  ['wonderful', 'stay'],
#  ['great', 'stay'],
#  ['short', 'stay', 'pleasant'],
#  ['preferred', 'place', 'business', 'cost', 'location', 'great'],
#  ['staff',
#   'kind',
#   'efficient',
#   'overall',
#   'experience',
#   'great',
#   'second',
#   'time',
#   'room',
#   'window',
#   'small',
#   'nice',
#   'atmosphere',
#   'neghiborhood',
#   'great'],
#  ['great',
#   'thrill',
#   'hostel',
#   'private',
#   'room',
#   'main',
#   'purpose',
#   'roof',
#   'head',
#   'hour',
#   'city',
#   'good',
#   'option',
#   'central',
#   'easy'],
#  ['pleasant',
#   'stay',
#   'close',
#   'bugis',
#   'station',
#   'min',
#   'convenient',
#   'host',
#   'friendly',
#   'helpful',
#   'notice',
#   'board',
#   'place',
#   'direction',
#   'landmark',
#   'hostel',
#   'room',
#   'bed',
#   'clean',
#   'toilet',
#   'head',
#   'hostel',
#   'next',
#   'mosque',
#   'prayer',
#   'time',
#   'day',
#   'free',
#   'wake',
#   'call',
#   'sunrise',
#   'good',
#   'place',
#   'budget'],
#  ['room',
#   'small',
#   'toiletry',
#   'amenity',
#   'tv',
#   'decoration',
#   'extra',
#   'charge',
#   'basic',
#   'need',
#   'stay',
#   'hostel',
#   'convenient',
#   'thing',
#   'storage',
#   'usd',
#   'pc',
#   'well',
#   'hostel'],
#  ['host', 'nice', 'helpful'],
#  ['central',
#   'friendly',
#   'clean',
#   'people',
#   'room',
#   'little',
#   'bit',
#   'big',
#   'room',
#   'small',
#   'mark',
#   'reception',
#   'bathroom',
#   'fine',
#   'clean',
#   'flip',
#   'flop',
#   'available',
#   'fridge',
#   'available',
#   'use',
#   'kettle',
#   'boiling',
#   'water',
#   'good',
#   'bed',
#   'aware',
#   'season',
#   'month',
#   'loud',
#   'neighbor',
#   'midnight'],
#  ['room', 'small', 'bathroom', 'clean'],
#  ['clean',
#   'room',
#   'glad',
#   'late',
#   'check',
#   'fast',
#   'internet',
#   'room',
#   'window',
#   'toilet',
#   'adorable',
#   'place',
#   'mall'],
#  ['host',
#   'open',
#   'arm',
#   'lot',
#   'information',
#   'room',
#   'direction',
#   'great',
#   'sightseeing',
#   'location',
#   'restaurant',
#   'help'],
#  ['room',
#   'mid',
#   'town',
#   'public',
#   'transit',
#   'water',
#   'cent',
#   'great',
#   'offer',
#   'nice',
#   'host',
#   'helpful',
#   'available',
#   'time'],
#  ['host', 'am', 'check', 'long', 'flight', 'unsociable', 'check', 'hour'],
#  ['clean', 'host', 'nice'],
#  ['host',
#   'warm',
#   'room',
#   'clean',
#   'bathroom',
#   'improvement',
#   'wifi',
#   'internet',
#   'access',
#   'good'],
#  ['superb',
#   'hostel',
#   'wonderful',
#   'great',
#   'location',
#   'friendly',
#   'helpful',
#   'staff',
#   'good',
#   'location'],
#  ['superb',
#   'hostel',
#   'descent',
#   'fantastic',
#   'hospitality',
#   'service',
#   'staff',
#   'location',
#   'br',
#   'bathroom',
#   'shower',
#   'bit',
#   'improvement',
#   'wifi',
#   'amazing',
#   'overall',
#   'satisfying',
#   'experience'],
#  ['room', 'simple', 'location', 'good', 'host', 'friendly'],
#  ['super',
#   'superbhostel',
#   'good',
#   'restaurant',
#   'area',
#   'tourist',
#   'point',
#   'interest',
#   'malaysian',
#   'neighborhood',
#   'minute',
#   'km',
#   'room',
#   'small',
#   'clean',
#   'air',
#   'room',
#   'attractive',
#   'price',
#   'heat',
#   'blanket',
#   'bag',
#   'quiet',
#   'stay'],
#  ['good',
#   'place',
#   'good',
#   'value',
#   'great',
#   'receptionist',
#   'place',
#   'service',
#   'facility',
#   'clean',
#   'clean',
#   'only',
#   'deal',
#   'breaker',
#   'singing',
#   'night',
#   'advance'],
#  ['great',
#   'host',
#   'sure',
#   'hand',
#   'late',
#   'check',
#   'small',
#   'room',
#   'comfortable',
#   'clean',
#   'quiet',
#   'great',
#   'location'],
#  ['friendly', 'staff', 'convenient', 'location'],
#  ['great', 'convenient', 'free', 'stay'],
#  ['nice',
#   'stay',
#   'superb',
#   'hostel',
#   'short',
#   'trip',
#   'aircon',
#   'fi',
#   'room',
#   'useful'],
#  ['superb',
#   'hostel',
#   'station',
#   'easy',
#   'instruction',
#   'location',
#   'convenient',
#   'eatery',
#   'mall',
#   'room',
#   'small',
#   'ok',
#   'much',
#   'luggage',
#   'short',
#   'stay',
#   'shared',
#   'bathroom',
#   'clean',
#   'enough',
#   'reception',
#   'friendly',
#   'helpful'],
#  ['fantastic', 'stay'],
#  ['hotel',
#   'information',
#   'hotel',
#   'information',
#   'main',
#   'point',
#   'interest',
#   'city',
#   'room',
#   'little',
#   'small',
#   'enough',
#   'short',
#   'stay'],
#  ['great',
#   'place',
#   'night',
#   'load',
#   'place',
#   'distance',
#   'room',
#   'facility',
#   'gracious',
#   'host'],
#  ['professional', 'service', 'basic', 'needa'],
#  ['small',
#   'sufficient',
#   'room',
#   'short',
#   'term',
#   'excellent',
#   'area',
#   'helpful',
#   'staff'],
#  ['staff',
#   'nice',
#   'helpful',
#   'room',
#   'small',
#   'expectation',
#   'place',
#   'short',
#   'stay'],
#  ['great',
#   'experience',
#   'basic',
#   'accommodation',
#   'great',
#   'location',
#   'lot',
#   'cool',
#   'stuff',
#   'public',
#   'transportation',
#   'wifi',
#   'great',
#   'whole',
#   'process',
#   'easy',
#   'complaint'],
#  ['great',
#   'stay',
#   'nice',
#   'helpful',
#   'stay',
#   'superb',
#   'hostel',
#   'cheap',
#   'good',
#   'food',
#   'place',
#   'interest',
#   'thank',
#   'hospitality',
#   'assistance'],
#  ['good', 'small', 'space', 'tower', 'shampoo', 'low', 'price'],
#  ['good',
#   'reception',
#   'room',
#   'little',
#   'small',
#   'good',
#   'explorer',
#   'connectivity',
#   'great',
#   'stay'],
#  ['front',
#   'desk',
#   'helpful',
#   'informative',
#   'willing',
#   'location',
#   'great',
#   'center',
#   'good',
#   'food',
#   'place',
#   'pinpoint',
#   'spot'],
#  ['lively',
#   'buggis',
#   'area',
#   'hostel',
#   'tiny',
#   'affordable',
#   'room',
#   'surprising',
#   'degree',
#   'privacy',
#   'host',
#   'professional',
#   'helpful',
#   'willing',
#   'aware',
#   'room',
#   'small',
#   'western',
#   'standard',
#   'shower',
#   'bathroom',
#   'combo',
#   'uncomportable'],
#  ['room',
#   'comfortable',
#   'place',
#   'close',
#   'bugis',
#   'station',
#   'many',
#   'piece',
#   'good',
#   'advice',
#   'living',
#   'transportation',
#   'little',
#   'bit',
#   'hard',
#   'place',
#   'well',
#   'nearby',
#   'position',
#   'church'],
#  ['good', 'budget', 'hostel'],
#  ['location',
#   'convenient',
#   'transportation',
#   'shopping',
#   'only',
#   'thing',
#   'difficult',
#   'loud',
#   'music',
#   'worship',
#   'nearby',
#   'mosque',
#   'o',
#   'clock',
#   'morning'],
#  ['friendly',
#   'attentive',
#   'host',
#   'sure',
#   'nice',
#   'appartment',
#   'friendly',
#   'condo',
#   'good',
#   'location',
#   'min',
#   'walking',
#   'plenty',
#   'food',
#   'option'],
#  ['great',
#   'host',
#   'helpful',
#   'great',
#   'conversationnice',
#   'clean',
#   'place',
#   'location',
#   'convenient'],
#  ['place',
#   'night',
#   'vacation',
#   'location',
#   'map',
#   'airplane',
#   'noise',
#   'area',
#   'quiet',
#   'peaceful',
#   'residential',
#   'area',
#   'bus',
#   'quick',
#   'acce',
#   'east',
#   'end',
#   'pelatok',
#   'case',
#   'small',
#   'park',
#   'room',
#   'cozy',
#   'big',
#   'family',
#   'helpful',
#   'bad',
#   'much',
#   'time',
#   'good',
#   'first',
#   'step',
#   'world',
#   'airbnb'],
#  ['wonderful',
#   'house',
#   'amenity',
#   'proximity',
#   'bus',
#   'train',
#   'station',
#   'warm',
#   'host',
#   'expectation'],
#  ['perfect',
#   'close',
#   'airport',
#   'city',
#   'hour',
#   'city',
#   'center',
#   'bit',
#   'waste',
#   'time'],
#  ['wonderful',
#   'stay',
#   'week',
#   'place',
#   'front',
#   'lovely',
#   'garden',
#   'exquisite',
#   'green',
#   'parrot',
#   'big',
#   'abode',
#   'nest',
#   'close',
#   'airport',
#   'caretaker',
#   'family',
#   'wonderful',
#   'cleanliness',
#   'commendable',
#   'good',
#   'privacy',
#   'good',
#   'heartland',
#   'experience',
#   'din',
#   'rustle',
#   'crowded',
#   'city',
#   'area',
#   'kitchen',
#   'facility',
#   'internet',
#   'washer',
#   'available',
#   'place',
#   'future',
#   'great',
#   'family',
#   'vacation',
#   'chance'],
#  ['family',
#   'top',
#   'hospitality',
#   'stay',
#   'home',
#   'family',
#   'young',
#   'couple',
#   'business',
#   'solo',
#   'traveler',
#   'easy',
#   'access',
#   'bus',
#   'underground',
#   'taxi',
#   'ride',
#   'suntec',
#   'home',
#   'taxi',
#   'home',
#   'family',
#   'near',
#   'future',
#   'amazing',
#   'host'],
#  ['unfortunate',
#   'arround',
#   'pore',
#   'stay',
#   'place',
#   'clean',
#   'guesthouse',
#   'br',
#   'complain',
#   'coperative',
#   'trouble',
#   'way',
#   'near',
#   'few',
#   'day',
#   'hotel',
#   'only',
#   'disadvantage',
#   'distance',
#   'main',
#   'city',
#   'culture',
#   'toilet',
#   'soap',
#   'bare',
#   'cup',
#   'tea',
#   'morning',
#   'homely',
#   'ambience'],
#  ['positive',
#   'good',
#   'value',
#   'money',
#   'location',
#   'family',
#   'safe',
#   'place',
#   'decent',
#   'location',
#   'family',
#   'non',
#   'intrusive',
#   'prompt',
#   'response',
#   'email',
#   'text',
#   'message',
#   'br',
#   'negative',
#   'bathroom',
#   'child',
#   'friendly',
#   'shock',
#   'day',
#   'bathroom',
#   'co',
#   'towel',
#   'damp',
#   'evening',
#   'happy',
#   'value',
#   'money',
#   'travel',
#   'great',
#   'team',
#   'bit',
#   'personal'],
#  ['clean', 'nice', 'room', 'house', 'amazng', 'room', 'bit', 'small', 'adult'],
#  ['big',
#   'room',
#   'nice',
#   'comfortable',
#   'only',
#   'drawback',
#   'bathroom',
#   'other',
#   'room',
#   'uncomfortable',
#   'bathroom',
#   'room',
#   'lucky',
#   'other',
#   'room',
#   'house',
#   'big',
#   'spacious',
#   'host',
#   'nice',
#   'advice',
#   'tip',
#   'attendant',
#   'nice',
#   'pleasant',
#   'house',
#   'everyone',
#   'information',
#   'dog',
#   'house',
#   'nice',
#   'kid',
#   'experience',
#   'great',
#   'house',
#   'home'],
#  ['beautiful', 'house', 'room', 'spacious', 'train', 'station', 'bad', 'walk'],
#  ['room',
#   'small',
#   'comfy',
#   'aircon',
#   'small',
#   'refregirator',
#   'bathroom',
#   'neighbouring',
#   'room',
#   'wifi',
#   'signal',
#   'weak',
#   'room',
#   'area',
#   'quiet',
#   'house',
#   'spacious',
#   'night'],
#  ['flight',
#   'pm',
#   'house',
#   'guest',
#   'maid',
#   'room',
#   'am',
#   'morning',
#   'guest',
#   'taxi',
#   'room',
#   'good',
#   'air',
#   'conditioner',
#   'bathroom',
#   'little',
#   'different',
#   'second',
#   'bedroom',
#   'bathroom',
#   'next',
#   'time',
#   'host'],
#  ['room',
#   'airport',
#   'subway',
#   'line',
#   'convenient',
#   'room',
#   'bathroom',
#   'cleanliness',
#   'good',
#   'breakfast',
#   'rice',
#   'noodle',
#   'egg',
#   'bit',
#   'simple'],
#  ['house',
#   'townhouse',
#   'area',
#   'house',
#   'quiet',
#   'room',
#   'neat',
#   'landlady',
#   'taxi',
#   'driver',
#   'trip',
#   'airport',
#   'pleasure',
#   'regret',
#   'hard',
#   'house',
#   'well',
#   'map',
#   'future',
#   'mosquito'],
#  ['location',
#   'easy',
#   'map',
#   'room',
#   'comfortable',
#   'breakfast',
#   'delicious',
#   'hearty',
#   'host',
#   'maid',
#   'friendly',
#   'helpful',
#   'hostess',
#   'taxi',
#   'driver',
#   'convenient',
#   'taxi',
#   'airport',
#   'wifi',
#   'signal',
#   'weak',
#   'room',
#   'accessible',
#   'public',
#   'area'],
#  ['nice',
#   'stay',
#   'home',
#   'warm',
#   'friendly',
#   'family',
#   'helpful',
#   'son',
#   'airport',
#   'many',
#   'thank'],
#  ['airport', 'nice', 'staf'],
#  ['excellent', 'house', 'big', 'clean', 'home', 'house', 'owner', 'chance'],
#  ['welcoming', 'friend', 'room', 'advertised'],
#  ['soft',
#   'spoken',
#   'kind',
#   'sweet',
#   'person',
#   'comfortable',
#   'moment',
#   'place',
#   'room',
#   'facility',
#   'food',
#   'option',
#   'area',
#   'room',
#   'picture',
#   'room',
#   'least',
#   'antique',
#   'entire',
#   'house',
#   'antique',
#   'calm',
#   'clean',
#   'mattress',
#   'sofa',
#   'comfortable',
#   'great',
#   'sleep',
#   'long',
#   'day',
#   'work',
#   'refrigerator',
#   'snack',
#   'quick',
#   'food',
#   'munch',
#   'alone',
#   'room',
#   'perfect',
#   'romantic',
#   'area',
#   'quiet',
#   'calm',
#   'green',
#   'great',
#   'neighborhood',
#   'park',
#   'front'],
#  ['house',
#   'airport',
#   'old',
#   'untidy',
#   'sleep',
#   'night',
#   'dirty',
#   'much',
#   'hair',
#   'owener',
#   'good',
#   'job'],
#  ['good', 'stay', 'exhibition', 'seminar', 'expo', 'min', 'expo'],
#  ['nice', 'place'],
#  ['ride'],
#  ['house',
#   'spacious',
#   'host',
#   'friendly',
#   'quiet',
#   'residential',
#   'area',
#   'convenient',
#   'close',
#   'airport'],
#  ['friend', 'stay', 'nice', 'hope', 'next', 'time'],
#  ['welcoming',
#   'person',
#   'airport',
#   'place',
#   'central',
#   'obvious',
#   'fine',
#   'expo',
#   'city',
#   'center',
#   'minute',
#   'airport',
#   'taxi',
#   'cost',
#   'dollar',
#   'ok'],
#  ['room',
#   'house',
#   'bath',
#   'room',
#   'neighbour',
#   'room',
#   'airport',
#   'min',
#   'subway',
#   'station'],
#  ['super',
#   'wife',
#   'day',
#   'pleasant',
#   'stay',
#   'belinda',
#   'helpful',
#   'home',
#   'kitchen',
#   'washing',
#   'machine',
#   'water',
#   'purifier',
#   'etc',
#   'easy',
#   'accessible',
#   'clean',
#   'well',
#   'room',
#   'clean',
#   'spacious',
#   'person',
#   'place',
#   'upperchangi',
#   'road',
#   'belinda',
#   'wonderful',
#   'host'],
#  ['neat', 'clean', 'airport'],
#  ['home',
#   'host',
#   'mom',
#   'many',
#   'child',
#   'able',
#   'hesitation',
#   'support',
#   'response',
#   'next',
#   'time'],
#  ['airport',
#   'strong',
#   'rain',
#   'time',
#   'nice',
#   'place',
#   'min',
#   'airport',
#   'distance',
#   'station'],
#  ['great', 'place'],
#  ['great',
#   'host',
#   'nice',
#   'host',
#   'room',
#   'big',
#   'bed',
#   'aircon',
#   'night',
#   'close',
#   'perfect',
#   'place',
#   'layover',
#   'belinda',
#   'great',
#   'host'],
#  ['ideal',
#   'airport',
#   'location',
#   'car',
#   'ride',
#   'comfortable',
#   'people',
#   'great',
#   'host',
#   'hospitality',
#   'local',
#   'eat',
#   'luggage',
#   'am',
#   'great',
#   'stay'],
#  ['fantastic',
#   'host',
#   'room',
#   'comfortable',
#   'spacious',
#   'plenty',
#   'common',
#   'area',
#   'able',
#   'necessary',
#   'strong',
#   'wifi',
#   'connection',
#   'house',
#   'airport',
#   'nice',
#   'lady',
#   'stay'],
#  ['great', 'place'],
#  ['hot', 'water'],
#  ['nice', 'stay'],
#  ['understanding'],
#  ['convenient',
#   'location',
#   'airport',
#   'quick',
#   'communication',
#   'host',
#   'comfortable',
#   'space'],
#  ['good', 'short', 'stay', 'convenient', 'location', 'airport'],
#  ['nightmare', 'visa', 'departure', 'wife', 'aunty', 'fine'],
#  ['place', 'big', 'stylish'],
#  ['good', 'location', 'cleanliness', 'amenity'],
#  ['airport',
#   'night',
#   'location',
#   'problem',
#   'communication',
#   'nice',
#   'ice',
#   'water',
#   'night',
#   'hot',
#   'room'],
#  ['nice', 'place', 'amazing', 'hoste'],
#  ['host',
#   'amazing',
#   'home',
#   'room',
#   'small',
#   'tidy',
#   'good',
#   'air',
#   'condition',
#   'bathroom',
#   'clean',
#   'neat',
#   'internet',
#   'fast',
#   'other',
#   'facility',
#   'awesome',
#   'living',
#   'style',
#   'able',
#   'namaz',
#   'time',
#   'lot',
#   'lot',
#   'option',
#   'less',
#   'meal',
#   'nice',
#   'food',
#   'drink',
#   'room',
#   'window',
#   'r',
#   'few',
#   'room',
#   'basement',
#   'thank'],
#  ['great', 'stay', 'convenient', 'location', 'clean', 'affordable'],
#  ['cool'],
#  ['nice',
#   'experience',
#   'super',
#   'hospitality',
#   'clean',
#   'efficient',
#   'service',
#   'br',
#   'room',
#   'small',
#   'bright',
#   'airy',
#   'room',
#   'window',
#   'available',
#   'convenient'],
#  ['affordable',
#   'great',
#   'part',
#   'town',
#   'arab',
#   'street',
#   'personal',
#   'fave',
#   'mine',
#   'food',
#   'minute'],
#  ['price',
#   'room',
#   'satisfactory',
#   'place',
#   'place',
#   'need',
#   'bathroom',
#   'shower',
#   'same',
#   'stall',
#   'wet',
#   'big',
#   'deal',
#   'couple',
#   'night',
#   'only',
#   'thing',
#   'real',
#   'improvement',
#   'ant',
#   'issue',
#   'bathroom',
#   'floor'],
#  ['room',
#   'cramped',
#   'restriction',
#   'hot',
#   'mosque',
#   'am',
#   'morning',
#   'curtain',
#   'much',
#   'sleep',
#   'first',
#   'room',
#   'full',
#   'large',
#   'ant',
#   'room',
#   'few',
#   'small',
#   'ant',
#   'impressed',
#   'service',
#   'ant',
#   'message',
#   'am',
#   'room',
#   'minute',
#   'airbnb',
#   'price',
#   'expensive',
#   'webpage',
#   'bad',
#   'strict',
#   'cancellation',
#   'policy',
#   'option'],
#  ['pleasant', 'hotel', 'personnel', 'nice', 'room', 'clean'],
#  ['room', 'small', 'kindness', 'service', 'nice'],
#  ['location',
#   'acceptable',
#   'walking',
#   'distance',
#   'station',
#   'food',
#   'court',
#   'convenience',
#   'store',
#   'few',
#   'step',
#   'people',
#   'receptionist',
#   'friendly',
#   'helpful',
#   'place',
#   'common',
#   'area',
#   'room',
#   'clean',
#   'tidy',
#   'concept',
#   'maximum',
#   'privacy',
#   'sharing',
#   'space',
#   'satisfied',
#   'night'],
#  ['good', 'condition', 'place', 'food', 'bus', 'stop'],
#  ['good'],
#  ['description',
#   'loft',
#   'style',
#   'unique',
#   'privacy',
#   'room',
#   'good',
#   'wifi',
#   'super',
#   'host',
#   'tommy',
#   'friendly',
#   'help',
#   'embassy',
#   'car',
#   'day'],
#  ['nice',
#   'inexpensive',
#   'place',
#   'lot',
#   'food',
#   'option',
#   'public',
#   'transport',
#   'great',
#   'cafe',
#   'road',
#   'patient',
#   'helpful',
#   'phone',
#   'check',
#   'good',
#   'advice',
#   'thing',
#   'next',
#   'time'],
#  ['great',
#   'location',
#   'good',
#   'food',
#   'staff',
#   'nice',
#   'walking',
#   'distance',
#   'lavender',
#   'station'],
#  ['perfect', 'single', 'traveller'],
#  ['inn',
#   'nice',
#   'place',
#   'tourist',
#   'station',
#   'lavender',
#   'easy',
#   'customer',
#   'city',
#   'room',
#   'clean',
#   'nice',
#   'great'],
#  ['second',
#   'time',
#   'host',
#   'request',
#   'early',
#   'check',
#   'wifi',
#   'fast',
#   'room',
#   'big',
#   'many',
#   'local',
#   'shop',
#   'restaurant',
#   'station',
#   'inn',
#   'minute',
#   'house'],
#  ['short', 'good', 'budget', 'place'],
#  ['place',
#   'solo',
#   'traveller',
#   'couple',
#   'nice',
#   'comfy',
#   'place',
#   'bed',
#   'pillow',
#   'duvet',
#   'comfortable',
#   'alcove',
#   'nice',
#   'clean',
#   'small',
#   't',
#   'receptionist',
#   'peggy',
#   'doll',
#   'nice',
#   'friendly',
#   'helpful',
#   'stay'],
#  ['place', 'next', 'trip'],
#  ['stay', 'friendly', 'vibe', 'affordable', 'single', 'traveller'],
#  ['accommodation',
#   'safe',
#   'separate',
#   'room',
#   'clean',
#   'easy',
#   'such',
#   'affordable',
#   'accommodation',
#   'front',
#   'desk',
#   'cheap',
#   'ticket',
#   'front',
#   'desk',
#   'many',
#   'bus',
#   'station',
#   'subway',
#   'station',
#   'lavender',
#   'convenient',
#   'convenience',
#   'store',
#   'restaurant',
#   'attraction',
#   'famous',
#   'stadium',
#   'football',
#   'game',
#   'free',
#   'weekend',
#   'large',
#   'outdoor',
#   'swimming',
#   'pool',
#   'cheap',
#   'great',
#   'star',
#   'recommendation'],
#  ['easy', 'self', 'check', 'clean', 'room', 'washroom', 'satisfied'],
#  ['wonderful',
#   'time',
#   'blanc',
#   'innit',
#   'cleantidy',
#   'great',
#   'hospitality',
#   'tommy',
#   'faizaljust',
#   'wanna',
#   'guy'],
#  ['great',
#   'place',
#   'short',
#   'stay',
#   'alone',
#   'economic',
#   'well',
#   't',
#   'easy',
#   'first',
#   'sight',
#   'look',
#   'bay',
#   'window',
#   'white',
#   'decoration',
#   'quiet',
#   'confort',
#   'alcove',
#   'good',
#   'suprise',
#   'staff',
#   'main',
#   'attraction',
#   'city',
#   'use',
#   'public',
#   'transport',
#   'welcoming',
#   'helpful'],
#  ['clean', 'nice', 'place', 'good', 'place', 'tour'],
#  ['transportation',
#   'convenient',
#   'line',
#   't',
#   'airport',
#   'less',
#   'hour',
#   'addition',
#   'line',
#   'subway',
#   'station',
#   'convenient',
#   'stay',
#   'comfortable',
#   'small',
#   'room',
#   'hair',
#   'dryer'],
#  ['perfect', 'short', 'stay'],
#  ['own', 'private', 'stuff', 'such', 'towel', 'gel', 'shampoo', 'etc'],
#  ['absolute',
#   'gem',
#   'place',
#   'great',
#   'value',
#   'money',
#   'cool',
#   'neighborhood',
#   'perfect'],
#  ['good',
#   'cost',
#   'performance',
#   'bad',
#   'shower',
#   'room',
#   'little',
#   'difficult',
#   'toilet',
#   'shower',
#   'room',
#   'clothe',
#   'soaking',
#   'wet',
#   'shower',
#   'room',
#   'common',
#   'space',
#   'large',
#   'multiple',
#   'people',
#   'common',
#   'space',
#   'wifi',
#   'computer',
#   'water',
#   'coffee',
#   'etc'],
#  ['pleasant',
#   'day',
#   'location',
#   'room',
#   'fantastic',
#   'good',
#   'experience',
#   'airbnb'],
#  ['great', 'stay', 'staff', 'helpful', 'place'],
#  ['room', 'neat', 'clean', 'front', 'desk', 'service', 'attentive'],
#  ['host', 'help'],
#  ['door', 'room', 'lock', 'other', 'guest', 'walking', 'phone', 'night'],
#  ['good', 'easy', 'self', 'check', 'clean', 'nice', 'place'],
#  ['second',
#   'time',
#   'great',
#   'good',
#   'location',
#   'staff',
#   'helpful',
#   'professional',
#   'free',
#   'upgrade',
#   'double',
#   'queen',
#   'bed',
#   'thank'],
#  ['great', 'place'],
#  ['first',
#   'time',
#   'host',
#   'tommy',
#   'quick',
#   'response',
#   'favor',
#   'place',
#   'organized',
#   'area',
#   'convenient',
#   'faizal',
#   'place',
#   'friendly',
#   'helpful',
#   'place',
#   'tourist',
#   'cheap',
#   'deal',
#   'tour',
#   'city',
#   'famous',
#   'island'],
#  ['simple', 'convenient', 'perfect', 'palce'],
#  ['great',
#   'value',
#   'money',
#   'default',
#   'sightseeing',
#   'place',
#   'city',
#   'place',
#   'clean',
#   'good',
#   'common',
#   'area',
#   'clean',
#   'place',
#   'quiet',
#   'time',
#   'good',
#   'staff',
#   'friendly',
#   'helpful'],
#  ['great', 'stay', 'great', 'spot', 'lovely', 'pool', 'cheap', 'perfect'],
#  ['great', 'place', 'love', 'dark', 'night', 'quiet', 'appreciated'],
#  ['second', 'time', 'kind', 'staff', 'quiet', 'private', 'hostel'],
#  ['many', 'food', 'area'],
#  ['great', 'value', 'money', 'quick', 'business', 'trip', 'value'],
#  ['good', 'place', 'helpful', 'staff', 'thank'],
#  ['clean',
#   'picture',
#   'many',
#   'restaurant',
#   'metro',
#   'station',
#   'lavender',
#   'minute',
#   'great',
#   'host',
#   'great',
#   'tip',
#   'day'],
#  ['place',
#   'nice',
#   'small',
#   'hostel',
#   'metro',
#   'hotel',
#   'same',
#   'typical',
#   'singaporean',
#   'food',
#   'courte',
#   'different',
#   'kind',
#   'food',
#   'aunty',
#   'friendly',
#   'helpful',
#   'question',
#   'place',
#   'short',
#   'term',
#   'visitor'],
#  ['place',
#   'great',
#   'very',
#   'hostel',
#   'good',
#   'sense',
#   'community',
#   'other',
#   'guest',
#   'tommy',
#   'worker',
#   'faizal',
#   'great',
#   'guy',
#   'question',
#   'fun',
#   'easy',
#   'transportation',
#   'place'],
#  ['fantastic',
#   'location',
#   'close',
#   'load',
#   'eatery',
#   'clean',
#   'host',
#   'helpful',
#   'friendly'],
#  ['good',
#   'location',
#   'faizal',
#   'polite',
#   'friendly',
#   'stay',
#   'budget',
#   'stay'],
#  ['good', 'value', 'money', 'faizal', 'friendly', 'accomodating', 'budget'],
#  ['nice', 'pleasant', 'stay'],
#  ['good',
#   'place',
#   'accessible',
#   'lg',
#   'faisal',
#   'amicable',
#   'informative',
#   'br',
#   'problem',
#   'check',
#   'check',
#   'room',
#   'comfortable',
#   'warm',
#   'station',
#   'walkable',
#   'distance',
#   'lot',
#   'shop',
#   'good',
#   'stay'],
#  ['helpful',
#   'check',
#   'nice',
#   'place',
#   'convenient',
#   'location',
#   'line',
#   'private',
#   'room',
#   'separation',
#   'other',
#   'curtain',
#   'very',
#   'hostel'],
#  ['great', 'value'],
#  ['room',
#   'small',
#   'alcove',
#   'other',
#   'room',
#   'intimacy',
#   'staff',
#   'nice',
#   'helpful',
#   'place',
#   'low',
#   'budget',
#   'bed'],
#  ['kind', 'quick', 'communication', 'clean', 'reasonable', 'facility'],
#  ['day',
#   'stay',
#   'boutique',
#   'inn',
#   'min',
#   'station',
#   'city',
#   'centre',
#   'cityhall',
#   'raffle',
#   'place',
#   'popular',
#   'shopping',
#   'orchard',
#   'road',
#   'plenty',
#   'food',
#   'court',
#   'super',
#   'fair',
#   'price',
#   'late',
#   'night',
#   'eatout',
#   'grocery',
#   'convenient',
#   'staff',
#   'attentive',
#   'helpful',
#   'week',
#   'pregnant',
#   'fazail',
#   'door',
#   'alright',
#   'help',
#   'inn',
#   'flight',
#   'late',
#   'midnight',
#   'inn',
#   'storage',
#   'luggage',
#   'checkout',
#   'timing',
#   'full',
#   'day',
#   'last',
#   'day',
#   'friend',
#   'inn',
#   'luggage',
#   'night',
#   'time',
#   'airport',
#   'fazail',
#   'shower',
#   'inn',
#   'airport',
#   'morning',
#   'am',
#   'clean',
#   'cleaner',
#   'common',
#   'area',
#   'shower',
#   'room',
#   'washroom',
#   'dust',
#   'bean',
#   'daily',
#   'cleaner',
#   'bed',
#   'linen',
#   'room',
#   'stay',
#   'central',
#   'aircon',
#   'room',
#   'cool',
#   'day',
#   'room',
#   'fan',
#   'more',
#   'ventilation',
#   'table',
#   'mirror',
#   'i',
#   'beautiful',
#   'inn'],
#  ['night', 'ok', 'long', 'much', 'space', 'stuff'],
#  ['place',
#   'nice',
#   'host',
#   'helpful',
#   'gentle',
#   'communicative',
#   'place',
#   'clean',
#   'quiet',
#   'well'],
#  ['friendly',
#   'check',
#   'man',
#   'good',
#   'helpful',
#   'good',
#   'insider',
#   'tip',
#   'city',
#   'room',
#   'small',
#   'smelly',
#   'ventilator',
#   'bathroom',
#   'okay'],
#  ['night',
#   'place',
#   'nice',
#   'room',
#   'small',
#   'receptionist',
#   'nice',
#   'public',
#   'transport',
#   'nice',
#   'food',
#   'centre',
#   'value',
#   'money'],
#  ['simple',
#   'staff',
#   'reception',
#   'friendly',
#   'useful',
#   'facility',
#   'luggage',
#   'checkout'],
#  ['room',
#   'small',
#   'clean',
#   'staff',
#   'helpful',
#   'faizal',
#   'time',
#   'recommendation',
#   'place'],
#  ['great', 'location', 'city', 'activity'],
#  ['aunty', 'helpfull', 'convinient', 'place'],
#  ['friend',
#   'nice',
#   'accommodation',
#   'clean',
#   'nice',
#   'vibe',
#   'friend',
#   'heap'],
#  ['great', 'location', 'quiet', 'super', 'wifi', 'clean', 'room'],
#  ['place',
#   'night',
#   'staff',
#   'facility',
#   'amenity',
#   'sufficient',
#   'short',
#   'stay',
#   'bed',
#   'comfortable',
#   'baby',
#   'hostel',
#   'soundproof',
#   'noise',
#   'stay',
#   'problem',
#   'noise',
#   'other',
#   'disruption',
#   'convenience',
#   'store',
#   'snack',
#   'taxi',
#   'uber',
#   'driver',
#   'place',
#   'popular',
#   'area',
#   'close',
#   'bus',
#   'stop',
#   'transportation',
#   'huge',
#   'problem',
#   'light'],
#  ['night', 'great', 'experience', 'staff', 'common', 'area', 'clean'],
#  ['place', 'public', 'transport', 'min', 'lavender', 'station'],
#  ['nice',
#   'tommy',
#   'stuff',
#   'helpful',
#   'nice',
#   'place',
#   'clean',
#   'suitable',
#   'solo',
#   'traveler',
#   'only',
#   'thing',
#   'bathroom',
#   'room',
#   'tidy'],
#  ['price', 'performance', 'ratio', 'high', 'thai', 'food', 'stall', 'good'],
#  ['location',
#   'hotel',
#   'convenient',
#   'station',
#   'convenient',
#   'lot',
#   'restaurant',
#   'price',
#   'cheap',
#   'other',
#   'place',
#   'hotel',
#   'quiet',
#   'clean',
#   'mosquito',
#   'bite',
#   'indoor',
#   'temperature',
#   'suitable',
#   'good',
#   'next',
#   'time'],
#  ['small',
#   'space',
#   'bed',
#   'rest',
#   'common',
#   'space',
#   'many',
#   'small',
#   'bug',
#   'ant',
#   'ok',
#   'cheap',
#   'price'],
#  ['satisfied',
#   'location',
#   'close',
#   'subway',
#   'station',
#   'bus',
#   'convenient',
#   'many',
#   'food',
#   'shop',
#   'famous',
#   'pork',
#   'offal',
#   'soup',
#   'meter',
#   'delicious',
#   'scissor',
#   'curry',
#   'rice',
#   'meter',
#   'famous',
#   'meter',
#   'many',
#   'cafe',
#   'different',
#   'taste',
#   'house',
#   'loft',
#   'style',
#   'shop',
#   'owner',
#   'fluent',
#   'standard',
#   'rare'],
#  ['noise',
#   'sound',
#   'proof',
#   'main',
#   'issue',
#   'sound',
#   'late',
#   'check',
#   'guest',
#   'room',
#   'sound',
#   'proof',
#   'small',
#   'room',
#   'private',
#   'room',
#   'private'],
#  ['price',
#   'great',
#   'secure',
#   'easy',
#   'access',
#   'city',
#   'plaza',
#   'lot',
#   'great',
#   'service',
#   'detail',
#   'area',
#   'helpful'],
#  ['lovely',
#   'spot',
#   'good',
#   'cafe',
#   'beer',
#   'little',
#   'bunch',
#   'cute',
#   'street',
#   'clean',
#   'quiet',
#   'ear',
#   'plug',
#   'person',
#   'dorm'],
#  ['location',
#   'great',
#   'walking',
#   'distance',
#   'main',
#   'subway',
#   'line',
#   'hungry',
#   'dozen',
#   'food',
#   'option',
#   'few',
#   'step'],
#  ['nice', 'little', 'place', 'friendly', 'staff', 'easy'],
#  ['place',
#   'hostel',
#   'small',
#   'hotel',
#   'friendly',
#   'service',
#   'room',
#   'bit',
#   'small',
#   'comfortable',
#   'clean',
#   'air',
#   'condition',
#   'good',
#   'first',
#   'trip',
#   'area',
#   'close',
#   'little',
#   'metro',
#   'station',
#   'recommendation',
#   'host',
#   'great'],
#  ['nice',
#   'place',
#   'subway',
#   'station',
#   'less',
#   'minute',
#   'convenience',
#   'store',
#   'large',
#   'food',
#   'court',
#   'door',
#   'morning',
#   'night',
#   'considerate',
#   'thing',
#   'various',
#   'prompt',
#   'message',
#   'good',
#   'convenient',
#   'note',
#   'hotel',
#   'information',
#   'prompt',
#   'next',
#   'morning',
#   'traffic',
#   'smooth',
#   'lot',
#   'travel',
#   'suggestion',
#   'good',
#   'big',
#   'sister'],
#  ['o',
#   'clock',
#   'evening',
#   'self',
#   'service',
#   'check',
#   'process',
#   'landlord',
#   'room',
#   'minute',
#   'walk',
#   'station',
#   'landlord',
#   'obvious',
#   'route',
#   'plan',
#   'bathroom',
#   'toilet',
#   'several',
#   'enough',
#   'disadvantage',
#   'noisy',
#   'other',
#   'guest',
#   'good',
#   'sleeping',
#   'condition',
#   'suitable'],
#  ['great',
#   'location',
#   'distance',
#   'transport',
#   'link',
#   'variety',
#   'local',
#   'cafe',
#   'eatery',
#   'faizal',
#   'front',
#   'desk',
#   'amazing',
#   'great',
#   'advice',
#   'concept',
#   'alcove',
#   'wall',
#   'thin',
#   'light',
#   'last',
#   'night',
#   'only',
#   'alcove',
#   'well',
#   'sleep',
#   'tommy',
#   'wrong',
#   'day',
#   'hour'],
#  ['fantastic', 'place', 'afraid', 'next', 'time'],
#  ['good',
#   'stay',
#   'hotel',
#   'easy',
#   'people',
#   'good',
#   'sense',
#   'direction',
#   'hotel',
#   'letter',
#   'clear',
#   'explanation',
#   'guidance',
#   'room',
#   'helpful',
#   'nice',
#   'faizal',
#   'thank',
#   'only',
#   'bad',
#   'point',
#   'couple',
#   'same',
#   'alcove',
#   'room',
#   'noice',
#   'night',
#   'early',
#   'morning',
#   'good',
#   'thank',
#   'hotel'],
#  ['place',
#   'short',
#   'notice',
#   'prior',
#   'arrangement',
#   'host',
#   'time',
#   'detail',
#   'room',
#   'picture',
#   'share',
#   'bathroom',
#   'clean',
#   'time',
#   'convenience',
#   'issue',
#   'dormitory',
#   'neighbor',
#   'light',
#   'couple',
#   'night',
#   'other',
#   'room',
#   'light',
#   'noise'],
#  ['place',
#   'cute',
#   'cozy',
#   'spot',
#   'wonderful',
#   'area',
#   'town',
#   'great',
#   'food',
#   'distance',
#   'wonderful',
#   'stay',
#   'place',
#   'other',
#   'special',
#   'restaurant',
#   'recommendation',
#   'map'],
#  ['great',
#   'place',
#   'single',
#   'private',
#   'room',
#   'private',
#   'alcove',
#   'walking',
#   'distance',
#   'station',
#   'min',
#   'way',
#   'lot',
#   'shop',
#   't',
#   'min',
#   'thing',
#   'other',
#   'guest',
#   'noise',
#   'past',
#   'pm',
#   'other',
#   'alcove',
#   'other',
#   'place',
#   'clean',
#   'receptionist',
#   'faizal',
#   'nice',
#   'attentive',
#   'concern',
#   'good',
#   'stay'],
#  ['great',
#   'place',
#   'fantastic',
#   'staff',
#   'quick',
#   'solution',
#   'needthe',
#   'place',
#   'clean',
#   'stylish',
#   'location'],
#  ['awesome', 'night', 'cozy', 'place', 'cool', 'place'],
#  ['picture', 'receptionist', 'helpful', 'near', 'station', 'tourist', 'place'],
#  ['staff',
#   'hostel',
#   'amazing',
#   'help',
#   'useful',
#   'info',
#   'tourist',
#   'town',
#   'hostel',
#   'clean',
#   'location',
#   'perfect',
#   'neighbourhood',
#   'area',
#   'food',
#   'court',
#   'corner',
#   'beautiful',
#   'coffee',
#   'shop',
#   'street',
#   'supermarket',
#   'entrance',
#   'great',
#   'place',
#   'impeccable',
#   'management'],
#  ['towel', 'money'],
#  ['place',
#   'easy',
#   'affordable',
#   'distance',
#   'plenty',
#   'place',
#   'food',
#   'toasty',
#   'space',
#   'ac',
#   'private',
#   'area',
#   'bag',
#   'evening',
#   'city',
#   'flight',
#   'earplug',
#   'night',
#   'many',
#   'people'],
#  ['cozy',
#   'place',
#   'lot',
#   'store',
#   'cycling',
#   'place',
#   'corner',
#   'many',
#   'thank',
#   'faisal',
#   'assistance'],
#  ['private', 'room', 'nice', 'staff', 'helpful', 'little', 'dirty', 'placesw'],
#  ['warmth', 'convenience', 'good', 'sound', 'insulation'],
#  ['friend',
#   'listing',
#   'superb',
#   'recommendation',
#   'host',
#   'tommy',
#   'responsive',
#   'query',
#   'loft',
#   'style',
#   'alcove',
#   'interesting',
#   'many',
#   'place',
#   'house'],
#  ['stay',
#   'blanc',
#   'expectation',
#   'first',
#   'few',
#   'day',
#   'sick',
#   'lot',
#   'room',
#   'great',
#   'place',
#   'home',
#   'thank',
#   'amazing',
#   'host',
#   'aunty',
#   'clean',
#   'beautiful',
#   'earplug',
#   'eyemask',
#   'other',
#   'guest',
#   'loud',
#   'light',
#   'able',
#   'free',
#   'tea',
#   'water',
#   'blanc',
#   'inn',
#   'flight',
#   'night',
#   'thank'],
#  ['lot',
#   'hip',
#   'place',
#   'area',
#   'helpful',
#   'staff',
#   'recommendation',
#   'little',
#   'hot',
#   'night',
#   'door',
#   'aircon',
#   'place',
#   'clean',
#   'comfortable',
#   'value',
#   'money',
#   'hospitality'],
#  ['convenient',
#   'place',
#   'cute',
#   'clean',
#   'easy',
#   'access',
#   'other',
#   'transportation',
#   'destination',
#   'quick',
#   'response',
#   'host',
#   'question',
#   'place',
#   'visitor'],
#  ['receptionist',
#   'quick',
# ...
#   'well',
#   'loft',
#   'dark',
#   'smell',
#   'damp',
#   'dominant',
#   'dehumidifier',
#   'aircon',
#   'running'],
#  ['house',
#   'perfect',
#   'couple',
#   'little',
#   'expensive',
#   'service',
#   'excellent',
#   'kind',
#   'little',
#   'bit',
#   'expensive',
#   'little',
#   'noise',
#   'window',
#   'good',
#   'like'],
#  ['great', 'location', 'fantastic', 'service'],
#  ['cozy',
#   'little',
#   'studio',
#   'loft',
#   'cbd',
#   'communication',
#   'clear',
#   'beginning',
#   'quick',
#   'responsiveness',
#   'easy',
#   'check',
#   'apartment',
#   'high',
#   'ceiling',
#   'designer',
#   'great',
#   'use',
#   'space',
#   'amenity',
#   'good',
#   'shape',
#   'member',
#   'heritage',
#   'team',
#   'welcoming',
#   'great',
#   'effort',
#   'stay',
#   'comfortable',
#   'nice',
#   'treat',
#   'late',
#   'night',
#   'snack',
#   'apartment',
#   'heritage',
#   'team',
#   'quick',
#   'late',
#   'night',
#   'single',
#   'traveler',
#   'couple',
#   'corporate',
#   'traveler'],
#  ['great',
#   'space',
#   'excellent',
#   'central',
#   'location',
#   'line',
#   'easy',
#   'check',
#   'check',
#   'smooth'],
#  ['wrong', 'apartment', 'location', 'awesome'],
#  ['nice', 'apartment', 'comfortablethe', 'traffic', 'convenient'],
#  ['amazing',
#   'apartment',
#   'great',
#   'location',
#   'peaceful',
#   'getaway',
#   'place',
#   'clean',
#   'housekeepign',
#   'point',
#   'michelle',
#   'cherry',
#   'helpful',
#   'stay',
#   'wonderful',
#   'possible'],
#  ['gracious',
#   'day',
#   'excellent',
#   'communication',
#   'room',
#   'service',
#   'clean',
#   'functional',
#   'apartment',
#   'good',
#   'location'],
#  ['nice', 'place', 'good', 'host', 'responsive'],
#  ['ir', 'small', 'apartment'],
#  ['issue',
#   'late',
#   'check',
#   'service',
#   'unable',
#   'host',
#   'other',
#   'great',
#   'location',
#   'multiple',
#   'line',
#   'bus',
#   'nice',
#   'strip',
#   'restaurant',
#   'bar',
#   'must',
#   'amazing',
#   'local',
#   'food',
#   'mintue'],
#  ['excellent',
#   'location',
#   'cozy',
#   'host',
#   'prompt',
#   'professional',
#   'care',
#   'need',
#   'value',
#   'location',
#   'raffle',
#   'self',
#   'service',
#   'laundry',
#   'situation',
#   'bit',
#   'cleaning',
#   'cycle',
#   'duration',
#   'unclear',
#   'guest',
#   'item',
#   'glad'],
#  ['place',
#   'amazing',
#   'location',
#   'secure',
#   'entry',
#   'key',
#   'fob',
#   'door',
#   'elevator',
#   'lot',
#   'good',
#   'bar',
#   'amazing',
#   'taco',
#   'place',
#   'easy',
#   'distance',
#   'unit',
#   'necessity'],
#  ['apartment',
#   'clean',
#   'location',
#   'fantastic',
#   'bar',
#   'restaurant',
#   'min',
#   'walk',
#   'bugis',
#   'area',
#   'bugis',
#   'junction',
#   'mall',
#   'min',
#   'city',
#   'amenity',
#   'hotel',
#   'check',
#   'easy',
#   'easy',
#   'tall',
#   'cm',
#   'hard',
#   'lofted',
#   'bed',
#   'area',
#   'smell',
#   'curry',
#   'strong'],
#  ['great', 'place', 'central', 'lot', 'thing', 'quiet', 'neighborhood'],
#  ['delightful',
#   'stay',
#   'heritage',
#   'apartment',
#   'location',
#   'great',
#   'room',
#   'clean',
#   'suitable',
#   'person',
#   'short',
#   'stay',
#   'work',
#   'trip',
#   'ray',
#   'helpful',
#   'friendly',
#   'heritage'],
#  ['overall',
#   'amazing',
#   'stay',
#   'thank',
#   'quick',
#   'helpful',
#   'check',
#   'last',
#   'minute',
#   'place',
#   'clean',
#   'modern',
#   't',
#   'thing',
#   'free',
#   'laundry',
#   'washer',
#   'washing',
#   'powder',
#   'apple',
#   'tv',
#   'youtube',
#   'local',
#   'phone',
#   'call',
#   'datum',
#   'i',
#   'place'],
#  ['afraid',
#   'place',
#   'small',
#   'perfect',
#   'work',
#   'space',
#   'amazing',
#   'thoughtful',
#   'helpful',
#   'stay',
#   'sure'],
#  ['nice', 'clean', 'close', 'proximity', 'city', 'center'],
#  ['awesome',
#   'location',
#   'easy',
#   'lot',
#   'local',
#   'door',
#   'step',
#   'host',
#   'game',
#   'changer',
#   'care',
#   'responsive',
#   'star'],
#  ['comfortable',
#   'convenient',
#   'location',
#   'great',
#   'value',
#   'hour',
#   'easy',
#   'ray',
#   'friendly',
#   'responsive',
#   'great',
#   'help'],
#  ['quaint',
#   'lovely',
#   'loft',
#   'apartment',
#   'city',
#   'centre',
#   'safe',
#   'environment',
#   'good',
#   'security',
#   'arrangement',
#   'family',
#   'space',
#   'small',
#   'large',
#   'people',
#   'ground',
#   'level',
#   'wardrobe',
#   'kitchenette',
#   'microwave',
#   'electric',
#   'stove',
#   'small',
#   'fridge',
#   'small',
#   'study',
#   'dining',
#   'table',
#   'person',
#   'bathroom',
#   'upper',
#   'level',
#   'queen',
#   'size',
#   'loft',
#   'bed',
#   'tv',
#   'apple',
#   'tv',
#   'connection',
#   'location',
#   'perfect',
#   'key',
#   'tourist',
#   'location',
#   'km',
#   'radius',
#   'team',
#   'responsive',
#   'prompt',
#   'luggage',
#   'checkout',
#   'last',
#   'day',
#   'few',
#   'hour',
#   'airport'],
#  ['apartment',
#   'equipped',
#   'amentie',
#   'stay',
#   'future',
#   'apartment',
#   'responsive',
#   'problem',
#   'requirement',
#   'short',
#   'span',
#   'time'],
#  ['great',
#   'location',
#   'papis',
#   'taco',
#   'awesome',
#   'easy',
#   'bus',
#   'place',
#   'cosy',
#   'short',
#   'stay',
#   'br',
#   'fantastic',
#   'host',
#   'easy',
#   'thank'],
#  ['studio', 'perfect', 'side'],
#  ['heritage',
#   'apartment',
#   'good',
#   'choice',
#   'service',
#   'expectation',
#   'next',
#   'time',
#   'great',
#   'place',
#   'friend'],
#  ['pro',
#   'safe',
#   'excellent',
#   'location',
#   'close',
#   'bunch',
#   'good',
#   'museum',
#   'famous',
#   'raffle',
#   'hotel',
#   'historic',
#   'hainanese',
#   'street',
#   'many',
#   'bar',
#   'excellent',
#   'diverse',
#   'restaurant',
#   'option',
#   'block',
#   'walk',
#   'bus',
#   'stop',
#   'access',
#   'concierge',
#   'service',
#   'responsive',
#   'friendly',
#   'complimentary',
#   'laundry',
#   'big',
#   'win',
#   'sweaty',
#   'day',
#   'con',
#   'alarming',
#   'con',
#   'apartment',
#   'shower',
#   'situation',
#   'lack',
#   'long',
#   'day',
#   'sweating',
#   'relentless',
#   'heat',
#   'nice',
#   'shower',
#   'insurance',
#   'clean',
#   'apartment',
#   'trip',
#   'bit',
#   'concierge',
#   'service',
#   'different',
#   'apartment',
#   'help',
#   'trust',
#   'move',
#   'awful',
#   'shower',
#   'situation',
#   'picture',
#   'shower',
#   'other',
#   'apartment',
#   'rain',
#   'forest',
#   'shower',
#   'head',
#   'heated',
#   'water',
#   'line',
#   'nozzle',
#   'shower',
#   'head',
#   'weak',
#   'water',
#   'pressure',
#   'well',
#   'bucket',
#   'warm',
#   'water',
#   'cleaning',
#   'routine',
#   'way',
#   'apartment',
#   'small',
#   'loft',
#   'fun',
#   'stair',
#   'bed',
#   'long',
#   'day',
#   'stiff',
#   'legged',
#   'morning',
#   'perfect',
#   'person',
#   'narrow',
#   'big',
#   'suit',
#   'case'],
#  ['great',
#   'place',
#   'cozy',
#   'beautiful',
#   'design',
#   'stylish',
#   'value',
#   'money',
#   'easy',
#   'food',
#   'food',
#   'walkable',
#   'distance',
#   'walkable',
#   'lot',
#   'shopping',
#   'mall',
#   'suntec',
#   'city',
#   'host',
#   'great',
#   'problem',
#   'place',
#   'future'],
#  ['good', 'location'],
#  ['week',
#   'staff',
#   'nice',
#   'helpful',
#   'people',
#   'first',
#   'day',
#   'check',
#   'staff'],
#  ['heritage',
#   'apartment',
#   'reservation',
#   'room',
#   'original',
#   'place',
#   'maintenance',
#   'ray',
#   'charge',
#   'customer',
#   'service',
#   'internet',
#   'issue',
#   'fix',
#   'thank'],
#  ['heritage',
#   'apartment',
#   'good',
#   'business',
#   'travel',
#   'experience',
#   'location',
#   'cbd',
#   'central',
#   'business',
#   'district',
#   'host',
#   'responsive',
#   'apartment',
#   'amenity',
#   'procedure',
#   'flexible',
#   'luggage',
#   'next',
#   'trip'],
#  ['apartment',
#   'right',
#   'town',
#   'amazing',
#   'place',
#   'room',
#   'good',
#   'size',
#   'bed',
#   'trip',
#   'star'],
#  ['great',
#   'stay',
#   'apartment',
#   'hour',
#   'arrival',
#   'professional',
#   'apartment',
#   'modern',
#   'clean'],
#  ['location',
#   'house',
#   'good',
#   'convenient',
#   'merlion',
#   'museum',
#   'other',
#   'major',
#   'attraction',
#   'cityhall',
#   'subway',
#   'station',
#   'suitable',
#   'people',
#   'room',
#   'quiet',
#   'problem',
#   'hot',
#   'water',
#   'supply',
#   'grateful'],
#  [],
#  ['nice',
#   'clean',
#   'apartment',
#   'perfect',
#   'single',
#   'person',
#   'couple',
#   'heart',
#   'central',
#   'area',
#   'restaurant',
#   'shop',
#   'minute',
#   'hotel',
#   'garden',
#   'boat',
#   'minute',
#   'exercise',
#   'local',
#   'transportation',
#   'bus',
#   'mtr',
#   'easy',
#   'numerous',
#   'supervisor',
#   'apartment',
#   'ray',
#   'great',
#   'friendly',
#   'helpful',
#   'question',
#   'whatsapp',
#   'application',
#   'phone',
#   'life',
#   'br',
#   'heritage',
#   'apartment',
#   'first',
#   'experience'],
#  ['beautiful',
#   'modern',
#   'minimalist',
#   'property',
#   'clean',
#   'easy',
#   'access',
#   'helpful',
#   'polite',
#   'friendly',
#   'thank',
#   'future'],
#  ['good',
#   'stay',
#   'spacious',
#   'place',
#   'apartment',
#   'small',
#   'people',
#   'photo',
#   'illusion',
#   'big',
#   'reality',
#   'good',
#   'communication',
#   'apartment',
#   'thank'],
#  ['great', 'location', 'cozy', 'apartment', 'ideal', 'couple', 'close'],
#  ['heritage',
#   'apartment',
#   'welcoming',
#   'early',
#   'checkin',
#   'aware',
#   'tall',
#   'loft',
#   'big',
#   'hazardous'],
#  ['excellent'],
#  ['upgrade',
#   'boat',
#   'quay',
#   'stay',
#   'thankful',
#   'warm',
#   'hospitality',
#   'staff',
#   'helpful',
#   'friendly',
#   'same',
#   'service',
#   'attitude',
#   'meticulous',
#   'luggage',
#   'n',
#   'miscellaneous',
#   'enquiry',
#   'moment',
#   'day',
#   'home',
#   'smile',
#   'everyday',
#   'room',
#   'clean',
#   'bed',
#   'comfortable',
#   'many',
#   'thrilled',
#   'love',
#   'ample',
#   'choice',
#   'food',
#   'hungry',
#   'yr',
#   'stay',
#   'excellent',
#   'hospitality',
#   'good',
#   'work',
#   'thank'],
#  ['great',
#   'location',
#   'distance',
#   'raffle',
#   'city',
#   'shopping',
#   'centre',
#   'convenience',
#   'shop',
#   'alot',
#   'food',
#   'area'],
#  ['great',
#   'place',
#   'heritage',
#   'apartment',
#   'amazing',
#   'host',
#   'great',
#   'experience'],
#  ['worth',
#   'penny',
#   'guy',
#   'amazing',
#   'last',
#   'minute',
#   'possible',
#   'easy',
#   'great',
#   'hospitality',
#   'big',
#   'thank'],
#  ['favorite',
#   'stay',
#   'love',
#   'cozy',
#   'place',
#   'hospitality',
#   'absolute',
#   'place',
#   'such',
#   'great',
#   'location',
#   'worth',
#   'single',
#   'cent'],
#  ['place',
#   'great',
#   'location',
#   'good',
#   'restaurant',
#   'bar',
#   'distance',
#   'huge',
#   'mall',
#   'shopping',
#   'district',
#   'city',
#   'area',
#   'quiet',
#   'good',
#   'place',
#   'uninterrupted',
#   'bill',
#   'request'],
#  ['great', 'place', 'amazing', 'hospitality', 'easy', 'host', 'help'],
#  ['bill',
#   'friendly',
#   'responsive',
#   'query',
#   'place',
#   'clean',
#   'cozy',
#   'shopping',
#   'mall'],
#  ['place',
#   'unique',
#   'love',
#   'lighting',
#   'sure',
#   'vain',
#   'person',
#   'clean',
#   'food',
#   'drink',
#   'bill',
#   'great',
#   'job',
#   'bag',
#   'lost',
#   'friendly',
#   'goodluck'],
#  ['shn', 'shn', 'place', 'bill', 'supportive', 'helpful', 'shn'],
#  ['room', 'cozy', 'clean', 'perfect', 'couple', 'staycation'],
#  ['place',
#   'expectation',
#   'basic',
#   'amenity',
#   'clean',
#   'comfortable',
#   'accessible',
#   'shopping',
#   'mall',
#   'convenient',
#   'store',
#   'public',
#   'transport'],
#  ['good', 'location', 'loft', 'bed', 'tv'],
#  ['wonderful',
#   'location',
#   'local',
#   'eatery',
#   'posh',
#   'restaurant',
#   'shopping',
#   'subway',
#   'station',
#   'attraction'],
#  ['bill',
#   'friendly',
#   'helpful',
#   'great',
#   'hospitality',
#   'stay',
#   'quiet',
#   'location',
#   'great'],
#  ['good', 'location', 'stylist', 'place'],
#  ['friendly',
#   'helpful',
#   'stay',
#   'prompt',
#   'thorough',
#   'sure',
#   'fine',
#   'little',
#   'thing',
#   'whole',
#   'experience',
#   'great',
#   'stay'],
#  ['nice', 'place'],
#  ['bill',
#   'kind',
#   'hosting',
#   'prompt',
#   'assistance',
#   'need',
#   'last',
#   'min',
#   'reservation',
#   'place',
#   'couple',
#   'need',
#   'stylish',
#   'loft',
#   'television',
#   'netflix',
#   'comfy',
#   'desk',
#   'base',
#   'level',
#   'food',
#   'work',
#   'br',
#   'couple',
#   'convenience',
#   'shop',
#   'same',
#   'time',
#   'bugis',
#   'junction',
#   'min'],
#  ['cozy',
#   'cute',
#   'place',
#   'fact',
#   'netflix',
#   'apple',
#   'tv',
#   'friendly',
#   'meticulous',
#   'detailed',
#   'check',
#   'procedure',
#   'pleasant',
#   'stay'],
#  ['amazing',
#   'place',
#   'host',
#   'gem',
#   'good',
#   'host',
#   'airbnb',
#   'place',
#   'worth',
#   'penny',
#   'such',
#   'awesome',
#   'hospitality',
#   'host'],
#  ['location',
#   'awesome',
#   'connection',
#   'stable',
#   'room',
#   'intermittent',
#   'internet',
#   'connection',
#   'awesome',
#   'hospitality',
#   'responsiveness',
#   'question'],
#  ['asap',
#   'problem',
#   'sure',
#   'comfortable',
#   'place',
#   'service',
#   'good',
#   'smile',
#   'warm',
#   'cheerful',
#   'home',
#   'service'],
#  ['awesome', 'place'],
#  ['ambience', 'amazing', 'value', 'money', 'place'],
#  ['great', 'host', 'easy', 'touch', 'great', 'place', 'staycation'],
#  ['host',
#   'warm',
#   'hospitality',
#   'welcome',
#   'apartment',
#   'kempt',
#   'comfortable',
#   'layout',
#   'cosyness',
#   'place'],
#  ['nice', 'place', 'staycation'],
#  ['people', 'simplistic', 'style', 'airbnb', 'experience'],
#  ['place',
#   'city',
#   'hall',
#   'bugis',
#   'walking',
#   'distance',
#   'side',
#   'less',
#   'minute',
#   'lot',
#   'food',
#   'bar',
#   'apartment',
#   'couple',
#   'staycation'],
#  ['cosy', 'comfortable', 'space', 'useful', 'amenity', 'asset', 'area'],
#  ['warm',
#   'hospitality',
#   'friendly',
#   'helpful',
#   'check',
#   'location',
#   'wise',
#   'superb',
#   'middle',
#   'bugis',
#   'city',
#   'esplanade',
#   'few',
#   'minute',
#   'friend',
#   'staycation'],
#  [],
#  ['nice', 'place'],
#  ['worth',
#   'money',
#   'loft',
#   'cosy',
#   'bed',
#   'netflix',
#   'late',
#   'night',
#   'movie',
#   'special',
#   'thank',
#   'warm',
#   'hospitality',
#   'hassle',
#   'free',
#   'check',
#   'kind',
#   'welcoming',
#   'need',
#   'place'],
#  ['good', 'location', 'room', 'photo', 'cozy', 'clean'],
#  ['location',
#   'great',
#   'many',
#   'food',
#   'option',
#   'budget',
#   'place',
#   'short',
#   'quiet',
#   'getaway',
#   'place'],
#  ['clean',
#   'simple',
#   'loft',
#   'amenity',
#   'location',
#   'convenient',
#   'town',
#   'area',
#   'cafe',
#   'accessible',
#   'clarence',
#   'attentive',
#   'host',
#   'prompt',
#   'fast',
#   'response',
#   'welcoming',
#   'pleasant'],
#  ['cozy', 'home', 'great', 'location', 'helpful'],
#  ['location', 'awesome', 'great', 'staycation'],
#  ['warm',
#   'hospitality',
#   'quick',
#   'reply',
#   'staff',
#   'apartment',
#   'clean',
#   'comfy',
#   'accessible',
#   'central',
#   'location',
#   'friend',
#   'stay',
#   'staycation',
#   'next',
#   'time'],
#  ['cosy', 'environment', 'must', 'staycation', 'ambiance', 'place'],
#  ['nice', 'place', 'staycation', 'fingertipsfoodsdrinksetc'],
#  ['thankful',
#   'smoothness',
#   'check',
#   'process',
#   'food',
#   'suggestion',
#   'area',
#   'place',
#   'cosy',
#   'clean',
#   'location',
#   'superb',
#   'raffle',
#   'suntec',
#   'affordable',
#   'gem'],
#  ['room',
#   'nice',
#   'cozy',
#   'staff',
#   'friendly',
#   'approachable',
#   'bar',
#   'first',
#   'floor',
#   'good'],
#  ['accurate',
#   'representation',
#   'place',
#   'responsive',
#   'host',
#   'interesting',
#   'room',
#   'location'],
#  ['good',
#   'place',
#   'home',
#   'apple',
#   'tv',
#   'location',
#   'good',
#   'lot',
#   'amenity',
#   'drink',
#   'shopping',
#   'mall',
#   'city',
#   'bugis',
#   'junction',
#   'few',
#   'minute',
#   'distance',
#   'place',
#   'worth',
#   'value'],
#  ['wonderful',
#   'place',
#   'big',
#   'upper',
#   'area',
#   'good',
#   'service',
#   'nice',
#   'polite'],
#  ['stay'],
#  ['location', 'inclusive', 'amenity', 'worth', 'price', 'short', 'vacation'],
#  ['place',
#   'large',
#   'review',
#   'small',
#   'sufficient',
#   'induction',
#   'cooker',
#   'microwave',
#   'toaster',
#   'helpful',
#   'responsive',
#   'stay',
#   'sound',
#   'water',
#   'pipe',
#   'loud',
#   'whole',
#   'night',
#   'sensitive',
#   'sleep',
#   'noise',
#   'other',
#   'good',
#   'staycay'],
#  ['good', 'place'],
#  ['great', 'location', 'quiet', 'great', 'host', 'helpful'],
#  ['quiet',
#   'place',
#   'nearby',
#   'cbd',
#   'busstop',
#   'station',
#   'city',
#   'hall',
#   'distance',
#   'same',
#   'restaurant',
#   'bar',
#   'work',
#   'craving',
#   'br',
#   'simple',
#   'nice',
#   'place'],
#  ['good', 'place', 'staycation', 'love', 'one'],
#  ['great',
#   'place',
#   'arab',
#   'street',
#   'quick',
#   'access',
#   'esplanade',
#   'great',
#   'time'],
#  ['awesome', 'location', 'room'],
#  ['place',
#   'great',
#   'city',
#   'area',
#   'unit',
#   'accessible',
#   'various',
#   'shopping',
#   'district',
#   'city',
#   'hall'],
#  ['stay', 'heritage', 'good', 'perfect', 'couple'],
#  ['simple', 'clean', 'true', 'pic', 'great', 'place', 'quiet', 'stay'],
#  ['place',
#   'description',
#   'true',
#   'photo',
#   'loft',
#   'stay',
#   'cosy',
#   'day',
#   'check',
#   'smooth',
#   'process',
#   'available',
#   'text',
#   'case',
#   'question',
#   'great',
#   'stay'],
#  ...]

# %%
stop_words = stopwords.words('english')
stop_words.extend(["accomodation", "place", "re", "edu", "use", "br", "s","d", "be", "b", "comment",
                   "nil", "say", "stay", "appartment", "thank", "take" "day", "airbnb", "airbnbs",
                   "ve", "bk", "pk", "belinda"])

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

tokens = remove_stopwords(tokens)

# %%
# to ensure no empty values
data = data.dropna(axis=0, how='any')

# save data as csv file for version control.
data.to_csv("cleanedComp.csv")

# save last column "tokens" as text file, for easy retrieve during LDA topic modelling
with open("testFile.txt", "w", encoding = "utf-8", errors = "ignore") as file:
    file.write(str(tokens))

# %%
# ## compressed csv file, for smaller file size when push to GitHub & deployed
# data.to_csv("cleanedComp.bz2", compression="bz2")

# data = pd.read_csv("cleanedComp.bz2", compression="bz2")

# %% [markdown]
#   # Data Understanding

# %%
data = pd.read_csv("../datasetsUsed/cleanedComp.csv").drop(["Unnamed: 0"], axis=1)

# %%
# to segment the data by Country
sing = data[(data['Country'] == "Singapore")]
print("Sin: ", len(sing))

thai = data[(data['Country'] == "Thailand")]
print("Tha: ", len(thai))

turk = data[(data['Country'] == "Turkey")]
print("Tur: ", len(turk))
# Out:
# Sin:  33729
# Tha:  322908
# Tur:  483704

# %% [markdown]
# ### WordCloud

# %% [markdown]
# #### Singapore's cloud

# %%
# %matplotlib inline

# split sentences to get individual words
s = []
for line in sing['tokensForWordcloud']: 
    s.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(s)

# plot Word Cloud with word frequencies
wordcloud = WordCloud(
    width=1000, height=500,
    background_color ='white',
    max_words = 2000,
    stopwords = stopwords.words('english'),
    contour_width=3
   ).generate_from_frequencies(wordfreq)
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# #### Thailand's cloud

# %%
# split sentences to get individual words
s = []
for line in thai['tokensForWordcloud']: 
    s.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(s)

# plot Word Cloud with word frequencies
wordcloud = WordCloud(
    width=1000, height=500,
    background_color ='white',
    max_words = 2000,
    stopwords = stopwords.words('english'),
    contour_width=3
   ).generate_from_frequencies(wordfreq)
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# #### Turkey's cloud

# %%
# split sentences to get individual words
s = []
for line in turk['tokensForWordcloud']: 
    s.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(s)

# plot Word Cloud with word frequencies
wordcloud = WordCloud(
    width=1000, height=500,
    background_color ='white',
    max_words = 2000,
    stopwords = stopwords.words('english'),
    contour_width=3
   ).generate_from_frequencies(wordfreq)
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()
